# %%
from bs4 import BeautifulSoup
import pdb
import pandas as pd
import re
from datetime import datetime
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Verify base data
#
# Check that all 122 table entries made it into the raw data file

# %%
with open("data/pepperscale_data.html", "r") as raw_html:
    pepper_html = BeautifulSoup(raw_html, 'html.parser')
    prettified_html = pepper_html.prettify()
    
with open("data/prettified_pepperscale_data.html", "w") as f:
    f.write(prettified_html.encode('utf8'))

# %% [markdown]
# From spot check: tr class "even" and "odd" indicate top of row; there should be 122 entries, as there was on the site

# %%
len(pepper_html.find_all("tr", re.compile("even|odd")))
# Out:
# 122

# %% [markdown]
# ## Extract information

# %% [markdown]
# Process each pepper
#
# Schema
# - Name
# - Heat
# - Jalapeño Reference Point
# - Species
# - Origin
#
# Notes
#
# - Can drop "child" tags with detailed information because info is in "tr even/odd" tags and child tags don't have min/max values
# - Detailed information is unlabeled, but after min/max follows child tag order: "Heat", "JalRP", "Species", "Origin"

# %%
INFO_LABELS = ["name", "min_shu", "max_shu", "heat", "jrp", "species", "origin", "link"]

# %%
pepper_tags = pepper_html.find_all("tr", re.compile("even|odd"))

# %%
test_row = pepper_tags[0]
test_row
# Out:
# <tr class="odd parent" role="row"><td style="" tabindex="0">Bell Pepper</td><td><a href="http://www.pepperscale.com/bell-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a></td><td>0</td><td class="sorting_1">0</td><td style="display: none;">Mild</td><td style="display: none;">-8,000 to -2,500</td><td style="display: none;">annuum</td><td style="display: none;">Mexico and South America</td></tr>

# %%
def extract_info_from_row_tag(row_tag):
    """Extract pepper info from tag; ignore non-pepper-related info"""
    pepper_info = [element.text.encode("utf-8") for element in row_tag.contents if element.text != "pepperscale.com"]
    link = row_tag.find("a").get('href')
    return dict(zip(INFO_LABELS, pepper_info + [link]))

all_peppers = [extract_info_from_row_tag(pepper_row) for pepper_row in pepper_tags]
all_peppers
# Out:
# [{'heat': 'Mild',
#   'jrp': '-8,000 to -2,500',
#   'link': u'http://www.pepperscale.com/bell-pepper',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'Bell Pepper',
#   'origin': 'Mexico and South America',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -2,500',
#   'link': u'http://www.pepperscale.com/gypsy-pepper',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'Gypsy Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -2,500',
#   'link': u'http://www.pepperscale.com/purple-beauty-pepper',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'Purple Beauty Pepper',
#   'origin': 'South America',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -2,500',
#   'link': u'http://www.pepperscale.com/melrose-pepper',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'Melrose Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 - 2,500',
#   'link': u'http://www.pepperscale.com/peperone-di-senise/',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'Peperone Di Senise',
#   'origin': 'Italy',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-2,500 to -8,000',
#   'link': u'https://www.pepperscale.com/california-wonder-pepper/',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'California Wonder Pepper',
#   'origin': 'United States',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-2,500 to -8,000',
#   'link': u'https://www.pepperscale.com/carmen-pepper/',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'Carmen Pepper',
#   'origin': 'Italy',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -250',
#   'link': u'https://www.pepperscale.com/tangerine-dream-pepper/',
#   'max_shu': '100',
#   'min_shu': '0',
#   'name': 'Tangerine Dream Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-160 to -13',
#   'link': u'http://www.pepperscale.com/shishito-pepper',
#   'max_shu': '200',
#   'min_shu': '50',
#   'name': 'Shishito Pepper',
#   'origin': 'Japan',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -5',
#   'link': u'http://www.pepperscale.com/banana-pepper',
#   'max_shu': '500',
#   'min_shu': '0',
#   'name': 'Banana Pepper ',
#   'origin': 'South America',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-80 to -5',
#   'link': u'http://www.pepperscale.com/pepperoncini',
#   'max_shu': '500',
#   'min_shu': '100',
#   'name': 'Pepperoncini',
#   'origin': 'Italy',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-80 to -5',
#   'link': u'http://www.pepperscale.com/pimento-pepper',
#   'max_shu': '500',
#   'min_shu': '100',
#   'name': 'Pimento Pepper',
#   'origin': 'Unknown',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8000 to -5',
#   'link': u'http://www.pepperscale.com/trinidad-perfume/',
#   'max_shu': '500',
#   'min_shu': '0',
#   'name': 'Trinidad Perfume',
#   'origin': 'Caribbean',
#   'species': 'chinense'},
#  {'heat': 'Mild',
#   'jrp': '-3 to -16',
#   'link': u'https://www.pepperscale.com/santa-fe-grande-pepper/',
#   'max_shu': '700',
#   'min_shu': '500',
#   'name': 'Santa Fe Grande Pepper',
#   'origin': 'United States',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-10 to -3',
#   'link': u'http://www.pepperscale.com/holy-mole-pepper',
#   'max_shu': '800',
#   'min_shu': '700',
#   'name': 'Holy Mole Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8000 to -3',
#   'link': u'http://www.pepperscale.com/medusa-pepper',
#   'max_shu': '1000',
#   'min_shu': '1',
#   'name': 'Medusa Pepper',
#   'origin': 'Mexico, <br />\nSouth America',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-80 to -3',
#   'link': u'http://www.pepperscale.com/italian-long-hot-peppers',
#   'max_shu': '1000',
#   'min_shu': '100',
#   'name': 'Italian Long Hot Pepper',
#   'origin': 'Italy',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-80 to -3',
#   'link': u'http://www.pepperscale.com/cubanelle-pepper',
#   'max_shu': '1000',
#   'min_shu': '100',
#   'name': 'Cubanelle Pepper',
#   'origin': 'Italy, Cuba',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-16 to -3',
#   'link': u'http://www.pepperscale.com/piquillo-peppers',
#   'max_shu': '1000',
#   'min_shu': '500',
#   'name': 'Piquillo Peppers',
#   'origin': 'Spain',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-16 to -3',
#   'link': u'http://www.pepperscale.com/beaver-dam-pepper',
#   'max_shu': '1000',
#   'min_shu': '500',
#   'name': 'Beaver Dam Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -3',
#   'link': u'http://www.pepperscale.com/aji-dulce/',
#   'max_shu': '1000',
#   'min_shu': '0',
#   'name': 'Aji Dulce',
#   'origin': 'Caribbean',
#   'species': 'chinense'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -2',
#   'link': u'https://www.pepperscale.com/chilly-chili/',
#   'max_shu': '1000',
#   'min_shu': '1',
#   'name': 'Chilly Chili',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-3 to -80',
#   'link': u'https://www.pepperscale.com/mexibell-pepper/',
#   'max_shu': '1000',
#   'min_shu': '100',
#   'name': 'Mexibell Pepper',
#   'origin': 'United States',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-7 to -2',
#   'link': u'http://www.pepperscale.com/peppadew-pepper',
#   'max_shu': '1200',
#   'min_shu': '1100',
#   'name': 'Peppadew Pepper',
#   'origin': 'Africa',
#   'species': 'baccatum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to -2',
#   'link': u'http://www.pepperscale.com/aji-panca',
#   'max_shu': '1500',
#   'min_shu': '1000',
#   'name': 'Aji Panca',
#   'origin': 'Peru',
#   'species': 'baccatum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to -2',
#   'link': u'http://www.pepperscale.com/ancho-pepper',
#   'max_shu': '1500',
#   'min_shu': '1000',
#   'name': 'Ancho Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to -2',
#   'link': u'http://www.pepperscale.com/poblano-peppers',
#   'max_shu': '1500',
#   'min_shu': '1000',
#   'name': 'Poblano Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to 0',
#   'link': u'http://www.pepperscale.com/guindilla-pepper',
#   'max_shu': '2000',
#   'min_shu': '1000',
#   'name': 'Guindilla Pepper',
#   'origin': 'Spain',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to 0',
#   'link': u'https://www.pepperscale.com/kashmiri-chili/',
#   'max_shu': '2000',
#   'min_shu': '1000',
#   'name': 'Kashmiri Chili',
#   'origin': 'India',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-16 to 0',
#   'link': u'http://www.pepperscale.com/padron-pepper',
#   'max_shu': '2500',
#   'min_shu': '500',
#   'name': 'Padr\xc3\xb3n Pepper',
#   'origin': 'Spain',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-16 to 0',
#   'link': u'http://www.pepperscale.com/anaheim-pepper',
#   'max_shu': '2500',
#   'min_shu': '500',
#   'name': 'Anaheim Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to 0',
#   'link': u'http://www.pepperscale.com/chilaca-pepper',
#   'max_shu': '2500',
#   'min_shu': '1000',
#   'name': 'Chilaca Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to 0',
#   'link': u'http://www.pepperscale.com/pasilla-pepper',
#   'max_shu': '2500',
#   'min_shu': '1000',
#   'name': 'Pasilla Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-5 to 0',
#   'link': u'http://www.pepperscale.com/rocotillo-pepper',
#   'max_shu': '2500',
#   'min_shu': '1500',
#   'name': 'Rocotillo Pepper',
#   'origin': 'Peru',
#   'species': 'baccatum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to 0',
#   'link': u'http://www.pepperscale.com/cascabel-pepper',
#   'max_shu': '3000',
#   'min_shu': '1000',
#   'name': 'Cascabel Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '-3 to 0',
#   'link': u'http://www.pepperscale.com/mulato-pepper',
#   'max_shu': '3000',
#   'min_shu': '2500',
#   'name': 'Mulato Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-16 to 0',
#   'link': u'http://www.pepperscale.com/espelette-pepper',
#   'max_shu': '4000',
#   'min_shu': '500',
#   'name': 'Espelette Pepper',
#   'origin': 'France',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '-5 to equal',
#   'link': u'https://www.pepperscale.com/cajun-belle-pepper/',
#   'max_shu': '4000',
#   'min_shu': '500',
#   'name': 'Cajun Belle Pepper',
#   'origin': 'United States',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': u'http://www.pepperscale.com/cherry-bomb-pepper',
#   'max_shu': '5000',
#   'min_shu': '2500',
#   'name': 'Cherry Bomb Pepper',
#   'origin': 'United States',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': u'http://www.pepperscale.com/cowhorn-pepper',
#   'max_shu': '5000',
#   'min_shu': '2500',
#   'name': 'Cowhorn Pepper',
#   'origin': 'South America',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': u'http://www.pepperscale.com/guajillo-pepper',
#   'max_shu': '5000',
#   'min_shu': '2500',
#   'name': 'Guajillo Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '-5 to 0',
#   'link': u'http://www.pepperscale.com/numex-centennial/',
#   'max_shu': '5000',
#   'min_shu': '1000',
#   'name': 'NuMex Centennial',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': u'http://www.pepperscale.com/chimayo-pepper',
#   'max_shu': '6000',
#   'min_shu': '4000',
#   'name': 'Chimayo Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': u'http://www.pepperscale.com/sandia-pepper',
#   'max_shu': '7000',
#   'min_shu': '5000',
#   'name': 'Sandia Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '-3 to 0',
#   'link': u'http://www.pepperscale.com/hatch-peppers',
#   'max_shu': '8000',
#   'min_shu': '1000',
#   'name': 'Hatch Peppers',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': u'http://www.pepperscale.com/jalapeno-peppers',
#   'max_shu': '8000',
#   'min_shu': '2500',
#   'name': 'Jalape\xc3\xb1o Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': u'http://www.pepperscale.com/purple-jalapeno-pepper',
#   'max_shu': '8000',
#   'min_shu': '2500',
#   'name': 'Purple Jalape\xc3\xb1o Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': u'http://www.pepperscale.com/chipotle-pepper',
#   'max_shu': '8000',
#   'min_shu': '2500',
#   'name': 'Chipotle Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': u'http://www.pepperscale.com/puya-pepper',
#   'max_shu': '8000',
#   'min_shu': '5000',
#   'name': 'Puya Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': u'http://www.pepperscale.com/fresno-pepper',
#   'max_shu': '10000',
#   'min_shu': '2500',
#   'name': 'Fresno Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 4',
#   'link': u'http://www.pepperscale.com/hungarian-wax-pepper',
#   'max_shu': '10000',
#   'min_shu': '5000',
#   'name': 'Hungarian Wax Pepper',
#   'origin': 'Hungary',
#   'species': 'annuum'},
#  {'heat': '',
#   'jrp': '0 to 4',
#   'link': u'http://www.pepperscale.com/black-hungarian-pepper',
#   'max_shu': '10000',
#   'min_shu': '5000',
#   'name': 'Black Hungarian Pepper',
#   'origin': 'Hungary',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 4',
#   'link': u'http://www.pepperscale.com/aleppo-pepper',
#   'max_shu': '10000',
#   'min_shu': '10000',
#   'name': 'Aleppo Pepper',
#   'origin': 'Syria',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 9',
#   'link': u'http://www.pepperscale.com/peter-pepper',
#   'max_shu': '23000',
#   'min_shu': '10000',
#   'name': 'Peter Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 9',
#   'link': u'http://www.pepperscale.com/serrano-peppers',
#   'max_shu': '23000',
#   'min_shu': '10000',
#   'name': 'Serrano Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 9',
#   'link': u'http://www.pepperscale.com/sport-peppers',
#   'max_shu': '23000',
#   'min_shu': '10000',
#   'name': 'Sport Peppers',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 12',
#   'link': u'http://www.pepperscale.com/bishops-crown-pepper',
#   'max_shu': '30000',
#   'min_shu': '5000',
#   'name': "Bishop's Crown Pepper",
#   'origin': 'South America',
#   'species': 'baccatum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 12',
#   'link': u'http://www.pepperscale.com/bulgarian-carrot-pepper',
#   'max_shu': '30000',
#   'min_shu': '5000',
#   'name': 'Bulgarian Carrot Pepper',
#   'origin': 'Hungary',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 12',
#   'link': u'http://www.pepperscale.com/fish-pepper',
#   'max_shu': '30000',
#   'min_shu': '5000',
#   'name': 'Fish Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '4 to 12',
#   'link': u'http://www.pepperscale.com/bolivian-rainbow-pepper',
#   'max_shu': '30000',
#   'min_shu': '10000',
#   'name': 'Bolivian Rainbow Pepper',
#   'origin': 'Bolivia',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '2 to 12',
#   'link': u'http://www.pepperscale.com/manzano-pepper',
#   'max_shu': '30000',
#   'min_shu': '12000',
#   'name': 'Manzano Pepper',
#   'origin': 'South America',
#   'species': 'pubescens'},
#  {'heat': 'Medium',
#   'jrp': '4 to 12',
#   'link': u'http://www.pepperscale.com/black-pearl-pepper',
#   'max_shu': '30000',
#   'min_shu': '10000',
#   'name': 'Black Pearl Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '2 to 12',
#   'link': u'http://www.pepperscale.com/japones-pepper',
#   'max_shu': '30000',
#   'min_shu': '15000',
#   'name': 'Japones Pepper',
#   'origin': 'Japan',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '2 to 12',
#   'link': u'http://www.pepperscale.com/lemon-drop-pepper',
#   'max_shu': '30000',
#   'min_shu': '15000',
#   'name': 'Lemon Drop Pepper',
#   'origin': 'Peru',
#   'species': 'baccatum'},
#  {'heat': 'Medium',
#   'jrp': '2 to 12',
#   'link': u'http://www.pepperscale.com/chile-de-arbol',
#   'max_shu': '30000',
#   'min_shu': '15000',
#   'name': 'Chile De \xc3\x80rbol',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '3 to 12',
#   'link': u'http://www.pepperscale.com/jwala-pepper',
#   'max_shu': '30000',
#   'min_shu': '20000',
#   'name': 'Jwala Pepper',
#   'origin': 'India',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 16',
#   'link': u'https://www.pepperscale.com/hinkelhatz-pepper/',
#   'max_shu': '30000',
#   'min_shu': '5000',
#   'name': 'Hinkelhatz Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '3 to 16',
#   'link': u'http://www.pepperscale.com/black-cobra-pepper',
#   'max_shu': '40000',
#   'min_shu': '20000',
#   'name': 'Black Cobra Pepper',
#   'origin': 'South America',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': u'http://www.pepperscale.com/numex-twilight',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'NuMex Twilight',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': u'http://www.pepperscale.com/aji-amarillo',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'Aji Amarillo',
#   'origin': 'Peru',
#   'species': 'baccatum'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': u'http://www.pepperscale.com/aji-charapita',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'Aji Charapita',
#   'origin': 'Peru',
#   'species': 'chinense'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': u'http://www.pepperscale.com/aji-omnicolor',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'Aji Omnicolor',
#   'origin': 'Peru',
#   'species': 'baccatum'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': u'http://www.pepperscale.com/tabasco-pepper',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'Tabasco Pepper',
#   'origin': 'Costa Rica',
#   'species': 'frutescens'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': u'http://www.pepperscale.com/cayenne-pepper',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'Cayenne Pepper',
#   'origin': 'French Guyana',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '5 to 20',
#   'link': u'http://www.pepperscale.com/super-chili-pepper',
#   'max_shu': '50000',
#   'min_shu': '40000',
#   'name': 'Super Chili Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': u'https://www.pepperscale.com/rooster-spur-pepper/',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'Rooster Spur Pepper',
#   'origin': 'United States',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '5 to 24',
#   'link': u'http://www.pepperscale.com/pequin-pepper',
#   'max_shu': '60000',
#   'min_shu': '40000',
#   'name': 'Pequin Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '7 to 26',
#   'link': u'http://www.pepperscale.com/dundicut-pepper/',
#   'max_shu': '65000',
#   'min_shu': '55000',
#   'name': 'Dundicut Pepper',
#   'origin': 'Pakistan',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '6 to 30',
#   'link': u'http://www.pepperscale.com/tien-tsin-pepper',
#   'max_shu': '75000',
#   'min_shu': '50000',
#   'name': 'Tien Tsin Pepper',
#   'origin': 'China',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '9 to 32',
#   'link': u'http://www.pepperscale.com/prairie-fire-pepper',
#   'max_shu': '80000',
#   'min_shu': '70000',
#   'name': 'Prairie Fire Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '8 to 32',
#   'link': u'https://www.pepperscale.com/cheiro-roxa/',
#   'max_shu': '80000',
#   'min_shu': '60000',
#   'name': 'Cheiro Roxa',
#   'origin': 'Brazil',
#   'species': 'chinense'},
#  {'heat': 'Medium',
#   'jrp': '4 to 40',
#   'link': u'http://www.pepperscale.com/rocoto-pepper',
#   'max_shu': '100000',
#   'min_shu': '30000',
#   'name': 'Rocoto Pepper',
#   'origin': 'South America',
#   'species': 'pubescens'},
#  {'heat': 'Extra Hot',
#   'jrp': '6 to 40',
#   'link': u'http://www.pepperscale.com/malagueta-pepper',
#   'max_shu': '100000',
#   'min_shu': '50000',
#   'name': 'Malagueta Pepper',
#   'origin': 'Brazil',
#   'species': 'frutescens'},
#  {'heat': 'Extra Hot',
#   'jrp': '6 to 40',
#   'link': u'http://www.pepperscale.com/chiltepin-pepper',
#   'max_shu': '100000',
#   'min_shu': '50000',
#   'name': 'Chiltepin Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '6 to 40',
#   'link': u'http://www.pepperscale.com/thai-peppers',
#   'max_shu': '100000',
#   'min_shu': '50000',
#   'name': 'Thai Pepper',
#   'origin': 'Thailand',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '9 to 40',
#   'link': u'http://www.pepperscale.com/charleston-hot-pepper',
#   'max_shu': '100000',
#   'min_shu': '70000',
#   'name': 'Charleston Hot Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '10 to 40',
#   'link': u'https://www.pepperscale.com/siling-labuyo/',
#   'max_shu': '100000',
#   'min_shu': '80000',
#   'name': 'Siling Labuyo',
#   'origin': 'Phillipines',
#   'species': 'frutescens'},
#  {'heat': 'Extra Hot',
#   'jrp': '6 to 40',
#   'link': u'https://www.pepperscale.com/byadgi-chili/',
#   'max_shu': '100000',
#   'min_shu': '50000',
#   'name': 'Byadgi Chili',
#   'origin': 'India',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '12 to 120',
#   'link': u'http://www.pepperscale.com/datil-pepper',
#   'max_shu': '300000',
#   'min_shu': '100000',
#   'name': 'Datil Pepper',
#   'origin': 'USA',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '15 to 130',
#   'link': u'http://www.pepperscale.com/madame-jeanette-pepper',
#   'max_shu': '325000',
#   'min_shu': '125000',
#   'name': 'Madame Jeanette Pepper',
#   'origin': 'South America',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '16 to 130',
#   'link': u'https://www.pepperscale.com/devils-tongue-pepper/',
#   'max_shu': '325000',
#   'min_shu': '125000',
#   'name': 'Devil\xe2\x80\x99s Tongue Pepper',
#   'origin': 'USA',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '12 to 140',
#   'link': u'http://www.pepperscale.com/wiri-wiri-pepper',
#   'max_shu': '350000',
#   'min_shu': '100000',
#   'name': 'Wiri Wiri Pepper',
#   'origin': 'South America',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '12 to 140',
#   'link': u'http://www.pepperscale.com/scotch-bonnet-pepper',
#   'max_shu': '350000',
#   'min_shu': '100000',
#   'name': 'Scotch Bonnet Pepper',
#   'origin': 'Caribbean',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '12 to 140',
#   'link': u'http://www.pepperscale.com/habanero-pepper',
#   'max_shu': '350000',
#   'min_shu': '100000',
#   'name': 'Habanero Pepper',
#   'origin': 'South America',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '12 to 140',
#   'link': u'http://www.pepperscale.com/peruvian-white-habanero',
#   'max_shu': '350000',
#   'min_shu': '100000',
#   'name': 'Peruvian White Habanero',
#   'origin': 'Peru',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '12 to 140',
#   'link': u'http://www.pepperscale.com/goat-pepper',
#   'max_shu': '350000',
#   'min_shu': '100000',
#   'name': 'Goat Pepper',
#   'origin': 'Caribbean',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '18 to 140',
#   'link': u'http://www.pepperscale.com/aji-chombo/',
#   'max_shu': '350000',
#   'min_shu': '150000',
#   'name': 'Aji Chombo',
#   'origin': 'Panama',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '14 to 160',
#   'link': u'http://www.pepperscale.com/fatalii-pepper',
#   'max_shu': '400000',
#   'min_shu': '125000',
#   'name': 'Fatalii Pepper',
#   'origin': 'Africa',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '35 to 178',
#   'link': u'http://www.pepperscale.com/caribbean-red-habanero',
#   'max_shu': '445000',
#   'min_shu': '300000',
#   'name': 'Caribbean Red Habanero',
#   'origin': 'Mexico',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '44 to 231',
#   'link': u'http://www.pepperscale.com/red-savina-habanero',
#   'max_shu': '577000',
#   'min_shu': '350000',
#   'name': 'Red Savina Habanero',
#   'origin': 'USA',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '53 to 231',
#   'link': u'http://www.pepperscale.com/chocolate-habanero',
#   'max_shu': '577000',
#   'min_shu': '425000',
#   'name': 'Chocolate Habanero',
#   'origin': 'Jamaica',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '106 to 400',
#   'link': u'https://www.pepperscale.com/7-pot-bubblegum/',
#   'max_shu': '1000000',
#   'min_shu': '850000',
#   'name': '7 Pot Bubblegum',
#   'origin': 'United Kingdom',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '100 to 400',
#   'link': u'http://www.pepperscale.com/bhut-jolokia-chocolate',
#   'max_shu': '1001304',
#   'min_shu': '800000',
#   'name': 'Bhut Jolokia Chocolate',
#   'origin': 'India',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '107 to 417',
#   'link': u'http://www.pepperscale.com/ghost-pepper',
#   'max_shu': '1041427',
#   'min_shu': '855000',
#   'name': 'Ghost Pepper',
#   'origin': 'India',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '125 to 480',
#   'link': u'https://www.pepperscale.com/7-pot-pepper/',
#   'max_shu': '1200000',
#   'min_shu': '1000000',
#   'name': 'Trinidad 7 Pot Pepper',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '100 to 480',
#   'link': u'https://www.pepperscale.com/7-pot-jonah/',
#   'max_shu': '1200000',
#   'min_shu': '800000',
#   'name': '7 Pot Jonah',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '133 to 500',
#   'link': u'http://www.pepperscale.com/infinity-pepper',
#   'max_shu': '1250000',
#   'min_shu': '1067286',
#   'name': 'Infinity Pepper',
#   'origin': 'United Kingdom',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '100 to 507',
#   'link': u'https://www.pepperscale.com/7-pot-primo/',
#   'max_shu': '1268250',
#   'min_shu': '800000',
#   'name': '7 Pot Primo',
#   'origin': 'United States',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '125 to 520',
#   'link': u'https://www.pepperscale.com/7-pot-barrackpore/',
#   'max_shu': '1300000',
#   'min_shu': '1000000',
#   'name': '7 Pot Barrackpore',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '125 to 540',
#   'link': u'https://www.pepperscale.com/7-pot-brain-strain/',
#   'max_shu': '1350000',
#   'min_shu': '1000000',
#   'name': '7 Pot Brain Strain',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '113 to 553',
#   'link': u'https://www.pepperscale.com/naga-viper/',
#   'max_shu': '1382118',
#   'min_shu': '900000',
#   'name': 'Naga Viper',
#   'origin': 'United Kingdom',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '100 to 585',
#   'link': u'https://www.pepperscale.com/trinidad-scorpion-butch-t/',
#   'max_shu': '1463700',
#   'min_shu': '800000',
#   'name': 'Trinidad Scorpion \xe2\x80\x9cButch T\xe2\x80\x9d',
#   'origin': 'Australia',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '125 to 600',
#   'link': u'http://www.pepperscale.com/naga-morich',
#   'max_shu': '1500000',
#   'min_shu': '1000000',
#   'name': 'Naga Morich',
#   'origin': 'India',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '125 to 639',
#   'link': u'http://www.pepperscale.com/dorset-naga',
#   'max_shu': '1598227',
#   'min_shu': '1000000',
#   'name': 'Dorset Naga',
#   'origin': 'United Kingdom',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '109 to 742',
#   'link': u'https://www.pepperscale.com/7-pot-douglah/',
#   'max_shu': '1853986',
#   'min_shu': '923889',
#   'name': '7 Pot Douglah',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '150 to 800',
#   'link': u'http://www.pepperscale.com/trinidad-moruga-scorpion',
#   'max_shu': '2000000',
#   'min_shu': '1200000',
#   'name': 'Trinidad Moruga Scorpion',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '150 to 800',
#   'link': u'http://www.pepperscale.com/trinidad-scorpion-chocolate',
#   'max_shu': '2000000',
#   'min_shu': '1200000',
#   'name': 'Trinidad Scorpion Chocolate',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '175 to 880',
#   'link': u'http://www.pepperscale.com/carolina-reaper',
#   'max_shu': '2200000',
#   'min_shu': '1400000',
#   'name': 'Carolina Reaper',
#   'origin': 'USA',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '175 to 880',
#   'link': u'https://www.pepperscale.com/komodo-dragon-pepper/',
#   'max_shu': '2200000',
#   'min_shu': '1400000',
#   'name': 'Komodo Dragon Pepper',
#   'origin': 'United Kingdom',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '310 to 992',
#   'link': u'https://www.pepperscale.com/dragons-breath-pepper/',
#   'max_shu': '2480000',
#   'min_shu': '',
#   'name': 'Dragon\xe2\x80\x99s Breath Pepper',
#   'origin': 'United Kingdom',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '250 to 2,120',
#   'link': u'http://www.pepperscale.com/pepper-spray',
#   'max_shu': '5300000',
#   'min_shu': '2000000',
#   'name': 'Pepper Spray',
#   'origin': 'N/A',
#   'species': 'N/A'},
#  {'heat': 'Super Hot',
#   'jrp': '1,875 to 6,400',
#   'link': u'http://www.pepperscale.com/capsaicin',
#   'max_shu': '16000000',
#   'min_shu': '15000000',
#   'name': 'Pure Capsaicin',
#   'origin': 'N/A',
#   'species': 'N/A'}]

# %% [markdown]
# ## Validate & sanitize data

# %%
peppers_data = pd.DataFrame(all_peppers)[INFO_LABELS]
peppers_data.head()
# Out:
#                    name min_shu max_shu  heat               jrp species  \
# 0           Bell Pepper       0       0  Mild  -8,000 to -2,500  annuum
# 1          Gypsy Pepper       0       0  Mild  -8,000 to -2,500  annuum
# 2  Purple Beauty Pepper       0       0  Mild  -8,000 to -2,500  annuum
# 3        Melrose Pepper       0       0  Mild  -8,000 to -2,500  annuum
# 4    Peperone Di Senise       0       0  Mild    -8,000 - 2,500  annuum
#
#                      origin                                             link
# 0  Mexico and South America           http://www.pepperscale.com/bell-pepper
# 1                       USA          http://www.pepperscale.com/gypsy-pepper
# 2             South America  http://www.pepperscale.com/purple-beauty-pepper
# 3                       USA        http://www.pepperscale.com/melrose-pepper
# 4                     Italy   http://www.pepperscale.com/peperone-di-senise/

# %% [markdown]
# ### Names
#
# - Have to be unique

# %%
peppers_data["name"].nunique() == len(peppers_data)
# Out:
# True

# %% [markdown]
# ### Min/Max SHU (Scoville Heat Units)

# %%
# min/max currently strings
peppers_data["min_shu"].values[0]
# Out:
# '0'

# %%
def sanitize_shu(shu):
    """astype(errors="ignore") throwing NA error"""
    try:
        return int(shu)
    except:
        return None

# %%
peppers_data["min_shu"] = peppers_data["min_shu"].apply(sanitize_shu)
peppers_data["max_shu"] = peppers_data["max_shu"].apply(sanitize_shu)

# %%
peppers_data["min_shu"].describe()
# Out:
# count    1.210000e+02
# mean     3.168556e+05
# std      1.402494e+06
# min      0.000000e+00
# 25%      1.000000e+03
# 50%      1.000000e+04
# 75%      1.000000e+05
# max      1.500000e+07
# Name: min_shu, dtype: float64

# %%
peppers_data["max_shu"].describe()
# Out:
# count    1.220000e+02
# mean     4.729345e+05
# std      1.594848e+06
# min      0.000000e+00
# 25%      2.500000e+03
# 50%      3.000000e+04
# 75%      3.437500e+05
# max      1.600000e+07
# Name: max_shu, dtype: float64

# %% [markdown]
# ### JRP (Jalapeño reference point)

# %% [markdown]
# #### Fix malformed JRP ranges

# %%
# malformed jrp ranges
peppers_data["jrp"].str.contains("to").sum(), len(peppers_data)
# Out:
# (111, 122)

# %%
malformed_jrp = peppers_data[~peppers_data["jrp"].str.contains("to")]
malformed_jrp
# Out:
#                       name  min_shu  max_shu    heat             jrp species  \
# 4       Peperone Di Senise      0.0        0    Mild  -8,000 - 2,500  annuum
# 38      Cherry Bomb Pepper   2500.0     5000  Medium               0  annuum
# 39          Cowhorn Pepper   2500.0     5000  Medium               0  annuum
# 40         Guajillo Pepper   2500.0     5000  Medium               0  annuum
# 42          Chimayo Pepper   4000.0     6000  Medium               0  annuum
# 43           Sandia Pepper   5000.0     7000  Medium               0  annuum
# 45         Jalapeño Pepper   2500.0     8000  Medium               0  annuum
# 46  Purple Jalapeño Pepper   2500.0     8000  Medium               0  annuum
# 47         Chipotle Pepper   2500.0     8000  Medium               0  annuum
# 48             Puya Pepper   5000.0     8000  Medium               0  annuum
# 49           Fresno Pepper   2500.0    10000  Medium               0  annuum
#
#            origin                                               link
# 4           Italy     http://www.pepperscale.com/peperone-di-senise/
# 38  United States      http://www.pepperscale.com/cherry-bomb-pepper
# 39  South America          http://www.pepperscale.com/cowhorn-pepper
# 40         Mexico         http://www.pepperscale.com/guajillo-pepper
# 42            USA          http://www.pepperscale.com/chimayo-pepper
# 43            USA           http://www.pepperscale.com/sandia-pepper
# 45         Mexico        http://www.pepperscale.com/jalapeno-peppers
# 46         Mexico  http://www.pepperscale.com/purple-jalapeno-pepper
# 47         Mexico         http://www.pepperscale.com/chipotle-pepper
# 48         Mexico             http://www.pepperscale.com/puya-pepper
# 49            USA           http://www.pepperscale.com/fresno-pepper

# %%
def sanitize_jrp(jrp):
    jrp = jrp.replace("equal", "0")
    
    if jrp == "0":
        return [0,0]
    elif "to" not in jrp:
        return [int(val.replace(",", "")) for val in jrp.split(" - ")]
    return [int(val.replace(",", "")) for val in jrp.split(" to ")]


peppers_data[["min_jrp", "max_jrp"]] = pd.DataFrame(peppers_data["jrp"].apply(sanitize_jrp).values.tolist())
peppers_data.head()
# Out:
#                    name  min_shu  max_shu  heat               jrp species  \
# 0           Bell Pepper      0.0        0  Mild  -8,000 to -2,500  annuum
# 1          Gypsy Pepper      0.0        0  Mild  -8,000 to -2,500  annuum
# 2  Purple Beauty Pepper      0.0        0  Mild  -8,000 to -2,500  annuum
# 3        Melrose Pepper      0.0        0  Mild  -8,000 to -2,500  annuum
# 4    Peperone Di Senise      0.0        0  Mild    -8,000 - 2,500  annuum
#
#                      origin                                             link  \
# 0  Mexico and South America           http://www.pepperscale.com/bell-pepper
# 1                       USA          http://www.pepperscale.com/gypsy-pepper
# 2             South America  http://www.pepperscale.com/purple-beauty-pepper
# 3                       USA        http://www.pepperscale.com/melrose-pepper
# 4                     Italy   http://www.pepperscale.com/peperone-di-senise/
#
#    min_jrp  max_jrp
# 0    -8000    -2500
# 1    -8000    -2500
# 2    -8000    -2500
# 3    -8000    -2500
# 4    -8000     2500

# %% [markdown]
# ### Categoricals

# %% [markdown]
# #### Heat

# %%
peppers_data["heat"].value_counts(dropna=False)
# Out:
# Medium       42
# Mild         36
# Super Hot    24
# Extra Hot    19
#               1
# Name: heat, dtype: int64

# %%
# record needs to be sanitized -- but what heat is it?

peppers_data[peppers_data["heat"] == ""]
# Out:
#                       name  min_shu  max_shu heat     jrp species   origin  \
# 51  Black Hungarian Pepper   5000.0    10000       0 to 4  annuum  Hungary
#
#                                                  link  min_jrp  max_jrp
# 51  http://www.pepperscale.com/black-hungarian-pepper        0        4

# %%
peppers_data[(peppers_data["min_shu"] >= 5000) & (peppers_data["max_shu"] <= 10000)]
# Out:
#                       name  min_shu  max_shu    heat     jrp species   origin  \
# 43           Sandia Pepper   5000.0     7000  Medium       0  annuum      USA
# 48             Puya Pepper   5000.0     8000  Medium       0  annuum   Mexico
# 50    Hungarian Wax Pepper   5000.0    10000  Medium  0 to 4  annuum  Hungary
# 51  Black Hungarian Pepper   5000.0    10000          0 to 4  annuum  Hungary
# 52           Aleppo Pepper  10000.0    10000  Medium  0 to 4  annuum    Syria
#
#                                                  link  min_jrp  max_jrp
# 43           http://www.pepperscale.com/sandia-pepper        0        0
# 48             http://www.pepperscale.com/puya-pepper        0        0
# 50    http://www.pepperscale.com/hungarian-wax-pepper        0        4
# 51  http://www.pepperscale.com/black-hungarian-pepper        0        4
# 52           http://www.pepperscale.com/aleppo-pepper        0        4

# %%
peppers_data["heat"] = peppers_data["heat"].apply(lambda x: x if x != "" else "Medium")
peppers_data["heat"].value_counts()
# Out:
# Medium       43
# Mild         36
# Super Hot    24
# Extra Hot    19
# Name: heat, dtype: int64

# %% [markdown]
# #### Species

# %%
peppers_data["species"].value_counts()
# Out:
# annuum        72
# chinense      36
# baccatum       7
# frutescens     3
# N/A            2
# pubescens      2
# Name: species, dtype: int64

# %%
peppers_data["species"] = peppers_data["species"].apply(lambda x: x if x != "N/A" else None)
peppers_data["species"].value_counts(dropna=False)
# Out:
# annuum        72
# chinense      36
# baccatum       7
# frutescens     3
# pubescens      2
# NaN            2
# Name: species, dtype: int64

# %% [markdown]
# #### Origin

# %%
peppers_data["origin"].value_counts()
# Out:
# USA                              24
# Mexico                           17
# South America                    10
# Trinidad                          7
# United States                     7
# Peru                              7
# United Kingdom                    6
# India                             6
# Italy                             4
# Caribbean                         4
# Spain                             3
# Hungary                           3
# N/A                               2
# Japan                             2
# Brazil                            2
# Africa                            2
# Pakistan                          1
# French Guyana                     1
# Mexico and South America          1
# China                             1
# Phillipines                       1
# Unknown                           1
# Panama                            1
# Syria                             1
# Italy, Cuba                       1
# Jamaica                           1
# France                            1
# Mexico, <br />\nSouth America     1
# Costa Rica                        1
# Bolivia                           1
# Thailand                          1
# Australia                         1
# Name: origin, dtype: int64

# %%
def sanitize_origin(origin):
    if pd.isnull(origin):
        return origin
    elif "Mexico" in origin and "South America" in origin:
        return "Mexico, South America"
    elif origin in ["USA", "United States"]:
        return "United States of America"
    elif origin not in ["N/A", "Unknown"]:
        return origin
    
peppers_data["origin"] = peppers_data["origin"].apply(sanitize_origin)
peppers_data["origin"].value_counts(dropna=False)
# Out:
# United States of America    31
# Mexico                      17
# South America               10
# Trinidad                     7
# Peru                         7
# India                        6
# United Kingdom               6
# Italy                        4
# Caribbean                    4
# Spain                        3
# NaN                          3
# Hungary                      3
# Mexico, South America        2
# Brazil                       2
# Africa                       2
# Japan                        2
# French Guyana                1
# Phillipines                  1
# Panama                       1
# Syria                        1
# Thailand                     1
# Pakistan                     1
# Costa Rica                   1
# China                        1
# Bolivia                      1
# Italy, Cuba                  1
# Jamaica                      1
# Australia                    1
# France                       1
# Name: origin, dtype: int64

# %% [markdown]
# ##### Add region
#
# Regions from here: https://www.thoughtco.com/official-listing-of-countries-world-region-1435153

# %%
def add_region(origin):
    if origin in ["Italy", "United Kingdom", "Spain", "Hungary", "France"]:
        return "Europe"
    elif origin in ["United States of America", "Mexico"]:
        return "North America"
    elif origin in ["Trinidad", "Caribbean", "Jamaica",  "Panama", "Costa Rica"]:
        return "Central America and the Caribbean"
    elif origin in ["Peru", "Brazil", "Bolivia", "French Guyana", "South America"]:
        return "South America"
    elif origin in ["India", "Pakistan", "Thailand", "Japan", "China", "Phillipines"]:
        return "Asia"
    elif origin in ["Africa"]:
        return "Africa"
    elif origin in ["Australia"]:
        return "Australia and Oceania"
    elif origin in ["Syria"]:
        return "Middle East"
    elif pd.notnull(origin):
        return "Multi-Region"
    
peppers_data["region"] = peppers_data["origin"].apply(add_region)
peppers_data[["origin", "region"]].drop_duplicates()
# Out:
#                        origin                             region
# 0       Mexico, South America                       Multi-Region
# 1    United States of America                      North America
# 2               South America                      South America
# 4                       Italy                             Europe
# 8                       Japan                               Asia
# 11                       None                               None
# 12                  Caribbean  Central America and the Caribbean
# 17                Italy, Cuba                       Multi-Region
# 18                      Spain                             Europe
# 23                     Africa                             Africa
# 24                       Peru                      South America
# 25                     Mexico                      North America
# 28                      India                               Asia
# 36                     France                             Europe
# 50                    Hungary                             Europe
# 52                      Syria                        Middle East
# 59                    Bolivia                      South America
# 72                 Costa Rica  Central America and the Caribbean
# 73              French Guyana                      South America
# 77                   Pakistan                               Asia
# 78                      China                               Asia
# 80                     Brazil                      South America
# 84                   Thailand                               Asia
# 86                Phillipines                               Asia
# 96                     Panama  Central America and the Caribbean
# 100                   Jamaica  Central America and the Caribbean
# 101            United Kingdom                             Europe
# 104                  Trinidad  Central America and the Caribbean
# 111                 Australia              Australia and Oceania

# %% [markdown]
# ## Convert to JSON
#
# References:
# - https://json-ld.org/spec/latest/json-ld-api-best-practices/
# - https://www.sitepoint.com/google-maps-json-file/

# %%
JSON_COLS = ["name", "species", "heat", "region", "origin", "min_shu", "max_shu", "min_jrp", "max_jrp", "link"]
json_peppers_data = peppers_data[JSON_COLS]
json_peppers_data.head()
# Out:
#                    name species  heat         region  \
# 0           Bell Pepper  annuum  Mild   Multi-Region
# 1          Gypsy Pepper  annuum  Mild  North America
# 2  Purple Beauty Pepper  annuum  Mild  South America
# 3        Melrose Pepper  annuum  Mild  North America
# 4    Peperone Di Senise  annuum  Mild         Europe
#
#                      origin  min_shu  max_shu  min_jrp  max_jrp  \
# 0     Mexico, South America      0.0        0    -8000    -2500
# 1  United States of America      0.0        0    -8000    -2500
# 2             South America      0.0        0    -8000    -2500
# 3  United States of America      0.0        0    -8000    -2500
# 4                     Italy      0.0        0    -8000     2500
#
#                                               link
# 0           http://www.pepperscale.com/bell-pepper
# 1          http://www.pepperscale.com/gypsy-pepper
# 2  http://www.pepperscale.com/purple-beauty-pepper
# 3        http://www.pepperscale.com/melrose-pepper
# 4   http://www.pepperscale.com/peperone-di-senise/

# %%
header_info = """{
    "source": "https://www.pepperscale.com/hot-pepper-list/",
    "contact": "https://github.com/alemosie",
    "last_updated": "%s",
    "peppers":
""" % (datetime.now())

with open ("data/peppers.json", "w") as json_file:
    json_file.write(header_info)
    json_file.write(json_peppers_data.to_json(orient='records'))
    json_file.write("}")
