# %%
from bs4 import BeautifulSoup
import requests
import pdb
import pandas as pd
import re
from datetime import datetime
import json
import matplotlib.pyplot as plt
import urllib2
# %matplotlib inline

# %% [markdown]
# ## Scrape data from site
#
# - Has to be AJAX post request, because the table is populated via JS and isn't fetched by BS
# - Nonces change daily, so they must be fetched dynamically

# %%
class ScrapePepperData():
    """Dynamically scrape hot pepper table data from PepperScale Hot Pepper List"""
    def __init__(self):
        self.headers = {
            "user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36(KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36"
        }
        self.base_url = "https://www.pepperscale.com/hot-pepper-list/"
        self.ajax_url = "https://www.pepperscale.com/wp-admin/admin-ajax.php/"
        self.data = self.scrape_page()
        
    def fetch_nonces(self):
        """Nonces are dynamically generated on a regular (daily?) basis, and need to be scraped from the 
        <script> tags at the time of the scraping request"""
        request = urllib2.Request(self.base_url, headers=self.headers)
        page_html = urllib2.urlopen(request).read()
        return re.findall('"nonce":"(\w+)"', page_html)

    def launch_ajax_request(self, nonce):
        """Submit a POST request to AJAX URL to get JS-generated table content"""
        request_fields = {
            "start": 0,
            "length": 10000,
            "action":"gv_datatables_data",
            "view_id": 10294,
            "nonce": nonce,
         }
        
        return requests.post(self.ajax_url, headers=self.headers, 
                             data=request_fields, json={"key":"value"}).json()["data"]
    
    def scrape_page(self):
        """Try all nonces found on the page until the Golden Nonce is revealed!"""
        nonces = self.fetch_nonces()
        for nonce in nonces:
            try:
                return self.launch_ajax_request(nonce)
            except:
                pass

# %%
pepper_scraper = ScrapePepperData()
raw_pepper_data = pepper_scraper.data
len(raw_pepper_data)
# Out:
# 122

# %%
INFO_LABELS = ["name", "link", "min_shu", "max_shu", "heat", "jrp", "species", "origin"]

def label_response_data(entry):
    labeled_entry = dict(zip(INFO_LABELS, entry))
    return labeled_entry

structured_pepper_data = [label_response_data(entry) for entry in raw_pepper_data]

# %% [markdown]
# ## Verify base static data
#
# Check that all 122 table entries made it into the raw data file

# %%
with open("../data/static_pepperscale_data.html", "r") as raw_html:
    pepper_html = BeautifulSoup(raw_html, 'html.parser')
    prettified_html = pepper_html.prettify()
    
with open("../data/static_prettified_pepperscale_data.html", "w") as f:
    f.write(prettified_html.encode('utf8'))

# %% [markdown]
# From spot check: tr class "even" and "odd" indicate top of row; there should be 122 entries, as there was on the site

# %%
len(pepper_html.find_all("tr", re.compile("even|odd")))
# Out:
# 122

# %% [markdown]
# ## Extract information

# %% [markdown]
# Process each pepper
#
# Schema
# - Name
# - Heat (SHU)
# - Jalapeño Reference Point
# - Species
# - Origin
# - Link
#
# Notes
#
# - Can drop "child" tags with detailed information because info is in "tr even/odd" tags and child tags don't have min/max values
# - Detailed information is unlabeled, but after min/max follows child tag order: "Heat", "JalRP", "Species", "Origin"
# - Account for unicode characters in pepper names

# %%
INFO_LABELS = ["name", "min_shu", "max_shu", "heat", "jrp", "species", "origin", "link"]

# %%
pepper_tags = pepper_html.find_all("tr", re.compile("even|odd"))

# %%
test_row = pepper_tags[0]
test_row
# Out:
# <tr class="odd parent" role="row"><td style="" tabindex="0">Bell Pepper</td><td><a href="http://www.pepperscale.com/bell-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a></td><td>0</td><td class="sorting_1">0</td><td style="display: none;">Mild</td><td style="display: none;">-8,000 to -2,500</td><td style="display: none;">annuum</td><td style="display: none;">Mexico and South America</td></tr>

# %%
def extract_info_from_row_tag(row_tag):
    """Extract pepper info from tag; ignore non-pepper-related info"""
    pepper_info = [element.text.encode("utf-8") for element in row_tag.contents if element.text != "pepperscale.com"]
#     link = row_tag.find("a").get('href')
    link = str(row_tag.find("a"))
    return dict(zip(INFO_LABELS, pepper_info + [link]))

all_peppers = [extract_info_from_row_tag(pepper_row) for pepper_row in pepper_tags]
all_peppers
# Out:
# [{'heat': 'Mild',
#   'jrp': '-8,000 to -2,500',
#   'link': '<a href="http://www.pepperscale.com/bell-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'Bell Pepper',
#   'origin': 'Mexico and South America',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -2,500',
#   'link': '<a href="http://www.pepperscale.com/gypsy-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'Gypsy Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -2,500',
#   'link': '<a href="http://www.pepperscale.com/purple-beauty-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'Purple Beauty Pepper',
#   'origin': 'South America',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -2,500',
#   'link': '<a href="http://www.pepperscale.com/melrose-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'Melrose Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 - 2,500',
#   'link': '<a href="http://www.pepperscale.com/peperone-di-senise/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'Peperone Di Senise',
#   'origin': 'Italy',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-2,500 to -8,000',
#   'link': '<a href="https://www.pepperscale.com/california-wonder-pepper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'California Wonder Pepper',
#   'origin': 'United States',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-2,500 to -8,000',
#   'link': '<a href="https://www.pepperscale.com/carmen-pepper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '0',
#   'min_shu': '0',
#   'name': 'Carmen Pepper',
#   'origin': 'Italy',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -250',
#   'link': '<a href="https://www.pepperscale.com/tangerine-dream-pepper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '100',
#   'min_shu': '0',
#   'name': 'Tangerine Dream Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-160 to -13',
#   'link': '<a href="http://www.pepperscale.com/shishito-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '200',
#   'min_shu': '50',
#   'name': 'Shishito Pepper',
#   'origin': 'Japan',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -5',
#   'link': '<a href="http://www.pepperscale.com/banana-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '500',
#   'min_shu': '0',
#   'name': 'Banana Pepper ',
#   'origin': 'South America',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-80 to -5',
#   'link': '<a href="http://www.pepperscale.com/pepperoncini" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '500',
#   'min_shu': '100',
#   'name': 'Pepperoncini',
#   'origin': 'Italy',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-80 to -5',
#   'link': '<a href="http://www.pepperscale.com/pimento-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '500',
#   'min_shu': '100',
#   'name': 'Pimento Pepper',
#   'origin': 'Unknown',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8000 to -5',
#   'link': '<a href="http://www.pepperscale.com/trinidad-perfume/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '500',
#   'min_shu': '0',
#   'name': 'Trinidad Perfume',
#   'origin': 'Caribbean',
#   'species': 'chinense'},
#  {'heat': 'Mild',
#   'jrp': '-3 to -16',
#   'link': '<a href="https://www.pepperscale.com/santa-fe-grande-pepper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '700',
#   'min_shu': '500',
#   'name': 'Santa Fe Grande Pepper',
#   'origin': 'United States',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-10 to -3',
#   'link': '<a href="http://www.pepperscale.com/holy-mole-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '800',
#   'min_shu': '700',
#   'name': 'Holy Mole Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8000 to -3',
#   'link': '<a href="http://www.pepperscale.com/medusa-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1000',
#   'min_shu': '1',
#   'name': 'Medusa Pepper',
#   'origin': 'Mexico, <br />\nSouth America',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-80 to -3',
#   'link': '<a href="http://www.pepperscale.com/italian-long-hot-peppers" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1000',
#   'min_shu': '100',
#   'name': 'Italian Long Hot Pepper',
#   'origin': 'Italy',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-80 to -3',
#   'link': '<a href="http://www.pepperscale.com/cubanelle-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1000',
#   'min_shu': '100',
#   'name': 'Cubanelle Pepper',
#   'origin': 'Italy, Cuba',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-16 to -3',
#   'link': '<a href="http://www.pepperscale.com/piquillo-peppers" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1000',
#   'min_shu': '500',
#   'name': 'Piquillo Peppers',
#   'origin': 'Spain',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-16 to -3',
#   'link': '<a href="http://www.pepperscale.com/beaver-dam-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1000',
#   'min_shu': '500',
#   'name': 'Beaver Dam Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -3',
#   'link': '<a href="http://www.pepperscale.com/aji-dulce/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1000',
#   'min_shu': '0',
#   'name': 'Aji Dulce',
#   'origin': 'Caribbean',
#   'species': 'chinense'},
#  {'heat': 'Mild',
#   'jrp': '-8,000 to -2',
#   'link': '<a href="https://www.pepperscale.com/chilly-chili/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1000',
#   'min_shu': '1',
#   'name': 'Chilly Chili',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-3 to -80',
#   'link': '<a href="https://www.pepperscale.com/mexibell-pepper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1000',
#   'min_shu': '100',
#   'name': 'Mexibell Pepper',
#   'origin': 'United States',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-7 to -2',
#   'link': '<a href="http://www.pepperscale.com/peppadew-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1200',
#   'min_shu': '1100',
#   'name': 'Peppadew Pepper',
#   'origin': 'Africa',
#   'species': 'baccatum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to -2',
#   'link': '<a href="http://www.pepperscale.com/aji-panca" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1500',
#   'min_shu': '1000',
#   'name': 'Aji Panca',
#   'origin': 'Peru',
#   'species': 'baccatum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to -2',
#   'link': '<a href="http://www.pepperscale.com/ancho-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1500',
#   'min_shu': '1000',
#   'name': 'Ancho Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to -2',
#   'link': '<a href="http://www.pepperscale.com/poblano-peppers" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1500',
#   'min_shu': '1000',
#   'name': 'Poblano Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to 0',
#   'link': '<a href="http://www.pepperscale.com/guindilla-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '2000',
#   'min_shu': '1000',
#   'name': 'Guindilla Pepper',
#   'origin': 'Spain',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to 0',
#   'link': '<a href="https://www.pepperscale.com/kashmiri-chili/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '2000',
#   'min_shu': '1000',
#   'name': 'Kashmiri Chili',
#   'origin': 'India',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-16 to 0',
#   'link': '<a href="http://www.pepperscale.com/padron-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '2500',
#   'min_shu': '500',
#   'name': 'Padr\xc3\xb3n Pepper',
#   'origin': 'Spain',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-16 to 0',
#   'link': '<a href="http://www.pepperscale.com/anaheim-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '2500',
#   'min_shu': '500',
#   'name': 'Anaheim Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to 0',
#   'link': '<a href="http://www.pepperscale.com/chilaca-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '2500',
#   'min_shu': '1000',
#   'name': 'Chilaca Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to 0',
#   'link': '<a href="http://www.pepperscale.com/pasilla-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '2500',
#   'min_shu': '1000',
#   'name': 'Pasilla Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-5 to 0',
#   'link': '<a href="http://www.pepperscale.com/rocotillo-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '2500',
#   'min_shu': '1500',
#   'name': 'Rocotillo Pepper',
#   'origin': 'Peru',
#   'species': 'baccatum'},
#  {'heat': 'Mild',
#   'jrp': '-8 to 0',
#   'link': '<a href="http://www.pepperscale.com/cascabel-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '3000',
#   'min_shu': '1000',
#   'name': 'Cascabel Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '-3 to 0',
#   'link': '<a href="http://www.pepperscale.com/mulato-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '3000',
#   'min_shu': '2500',
#   'name': 'Mulato Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Mild',
#   'jrp': '-16 to 0',
#   'link': '<a href="http://www.pepperscale.com/espelette-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '4000',
#   'min_shu': '500',
#   'name': 'Espelette Pepper',
#   'origin': 'France',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '-5 to equal',
#   'link': '<a href="https://www.pepperscale.com/cajun-belle-pepper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '4000',
#   'min_shu': '500',
#   'name': 'Cajun Belle Pepper',
#   'origin': 'United States',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': '<a href="http://www.pepperscale.com/cherry-bomb-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '5000',
#   'min_shu': '2500',
#   'name': 'Cherry Bomb Pepper',
#   'origin': 'United States',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': '<a href="http://www.pepperscale.com/cowhorn-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '5000',
#   'min_shu': '2500',
#   'name': 'Cowhorn Pepper',
#   'origin': 'South America',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': '<a href="http://www.pepperscale.com/guajillo-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '5000',
#   'min_shu': '2500',
#   'name': 'Guajillo Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '-5 to 0',
#   'link': '<a href="http://www.pepperscale.com/numex-centennial/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '5000',
#   'min_shu': '1000',
#   'name': 'NuMex Centennial',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': '<a href="http://www.pepperscale.com/chimayo-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '6000',
#   'min_shu': '4000',
#   'name': 'Chimayo Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': '<a href="http://www.pepperscale.com/sandia-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '7000',
#   'min_shu': '5000',
#   'name': 'Sandia Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '-3 to 0',
#   'link': '<a href="http://www.pepperscale.com/hatch-peppers" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '8000',
#   'min_shu': '1000',
#   'name': 'Hatch Peppers',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': '<a href="http://www.pepperscale.com/jalapeno-peppers" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '8000',
#   'min_shu': '2500',
#   'name': 'Jalape\xc3\xb1o Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': '<a href="http://www.pepperscale.com/purple-jalapeno-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '8000',
#   'min_shu': '2500',
#   'name': 'Purple Jalape\xc3\xb1o Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': '<a href="http://www.pepperscale.com/chipotle-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '8000',
#   'min_shu': '2500',
#   'name': 'Chipotle Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': '<a href="http://www.pepperscale.com/puya-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '8000',
#   'min_shu': '5000',
#   'name': 'Puya Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0',
#   'link': '<a href="http://www.pepperscale.com/fresno-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '10000',
#   'min_shu': '2500',
#   'name': 'Fresno Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 4',
#   'link': '<a href="http://www.pepperscale.com/hungarian-wax-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '10000',
#   'min_shu': '5000',
#   'name': 'Hungarian Wax Pepper',
#   'origin': 'Hungary',
#   'species': 'annuum'},
#  {'heat': '',
#   'jrp': '0 to 4',
#   'link': '<a href="http://www.pepperscale.com/black-hungarian-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '10000',
#   'min_shu': '5000',
#   'name': 'Black Hungarian Pepper',
#   'origin': 'Hungary',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 4',
#   'link': '<a href="http://www.pepperscale.com/aleppo-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '10000',
#   'min_shu': '10000',
#   'name': 'Aleppo Pepper',
#   'origin': 'Syria',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 9',
#   'link': '<a href="http://www.pepperscale.com/peter-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '23000',
#   'min_shu': '10000',
#   'name': 'Peter Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 9',
#   'link': '<a href="http://www.pepperscale.com/serrano-peppers" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '23000',
#   'min_shu': '10000',
#   'name': 'Serrano Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 9',
#   'link': '<a href="http://www.pepperscale.com/sport-peppers" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '23000',
#   'min_shu': '10000',
#   'name': 'Sport Peppers',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 12',
#   'link': '<a href="http://www.pepperscale.com/bishops-crown-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '30000',
#   'min_shu': '5000',
#   'name': "Bishop's Crown Pepper",
#   'origin': 'South America',
#   'species': 'baccatum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 12',
#   'link': '<a href="http://www.pepperscale.com/bulgarian-carrot-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '30000',
#   'min_shu': '5000',
#   'name': 'Bulgarian Carrot Pepper',
#   'origin': 'Hungary',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 12',
#   'link': '<a href="http://www.pepperscale.com/fish-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '30000',
#   'min_shu': '5000',
#   'name': 'Fish Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '4 to 12',
#   'link': '<a href="http://www.pepperscale.com/bolivian-rainbow-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '30000',
#   'min_shu': '10000',
#   'name': 'Bolivian Rainbow Pepper',
#   'origin': 'Bolivia',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '2 to 12',
#   'link': '<a href="http://www.pepperscale.com/manzano-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '30000',
#   'min_shu': '12000',
#   'name': 'Manzano Pepper',
#   'origin': 'South America',
#   'species': 'pubescens'},
#  {'heat': 'Medium',
#   'jrp': '4 to 12',
#   'link': '<a href="http://www.pepperscale.com/black-pearl-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '30000',
#   'min_shu': '10000',
#   'name': 'Black Pearl Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '2 to 12',
#   'link': '<a href="http://www.pepperscale.com/japones-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '30000',
#   'min_shu': '15000',
#   'name': 'Japones Pepper',
#   'origin': 'Japan',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '2 to 12',
#   'link': '<a href="http://www.pepperscale.com/lemon-drop-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '30000',
#   'min_shu': '15000',
#   'name': 'Lemon Drop Pepper',
#   'origin': 'Peru',
#   'species': 'baccatum'},
#  {'heat': 'Medium',
#   'jrp': '2 to 12',
#   'link': '<a href="http://www.pepperscale.com/chile-de-arbol" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '30000',
#   'min_shu': '15000',
#   'name': 'Chile De \xc3\x80rbol',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '3 to 12',
#   'link': '<a href="http://www.pepperscale.com/jwala-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '30000',
#   'min_shu': '20000',
#   'name': 'Jwala Pepper',
#   'origin': 'India',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '0 to 16',
#   'link': '<a href="https://www.pepperscale.com/hinkelhatz-pepper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '30000',
#   'min_shu': '5000',
#   'name': 'Hinkelhatz Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '3 to 16',
#   'link': '<a href="http://www.pepperscale.com/black-cobra-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '40000',
#   'min_shu': '20000',
#   'name': 'Black Cobra Pepper',
#   'origin': 'South America',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': '<a href="http://www.pepperscale.com/numex-twilight" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'NuMex Twilight',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': '<a href="http://www.pepperscale.com/aji-amarillo" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'Aji Amarillo',
#   'origin': 'Peru',
#   'species': 'baccatum'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': '<a href="http://www.pepperscale.com/aji-charapita" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'Aji Charapita',
#   'origin': 'Peru',
#   'species': 'chinense'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': '<a href="http://www.pepperscale.com/aji-omnicolor" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'Aji Omnicolor',
#   'origin': 'Peru',
#   'species': 'baccatum'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': '<a href="http://www.pepperscale.com/tabasco-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'Tabasco Pepper',
#   'origin': 'Costa Rica',
#   'species': 'frutescens'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': '<a href="http://www.pepperscale.com/cayenne-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'Cayenne Pepper',
#   'origin': 'French Guyana',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '5 to 20',
#   'link': '<a href="http://www.pepperscale.com/super-chili-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '50000',
#   'min_shu': '40000',
#   'name': 'Super Chili Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '4 to 20',
#   'link': '<a href="https://www.pepperscale.com/rooster-spur-pepper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '50000',
#   'min_shu': '30000',
#   'name': 'Rooster Spur Pepper',
#   'origin': 'United States',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '5 to 24',
#   'link': '<a href="http://www.pepperscale.com/pequin-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '60000',
#   'min_shu': '40000',
#   'name': 'Pequin Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '7 to 26',
#   'link': '<a href="http://www.pepperscale.com/dundicut-pepper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '65000',
#   'min_shu': '55000',
#   'name': 'Dundicut Pepper',
#   'origin': 'Pakistan',
#   'species': 'annuum'},
#  {'heat': 'Medium',
#   'jrp': '6 to 30',
#   'link': '<a href="http://www.pepperscale.com/tien-tsin-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '75000',
#   'min_shu': '50000',
#   'name': 'Tien Tsin Pepper',
#   'origin': 'China',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '9 to 32',
#   'link': '<a href="http://www.pepperscale.com/prairie-fire-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '80000',
#   'min_shu': '70000',
#   'name': 'Prairie Fire Pepper',
#   'origin': 'Mexico',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '8 to 32',
#   'link': '<a href="https://www.pepperscale.com/cheiro-roxa/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '80000',
#   'min_shu': '60000',
#   'name': 'Cheiro Roxa',
#   'origin': 'Brazil',
#   'species': 'chinense'},
#  {'heat': 'Medium',
#   'jrp': '4 to 40',
#   'link': '<a href="http://www.pepperscale.com/rocoto-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '100000',
#   'min_shu': '30000',
#   'name': 'Rocoto Pepper',
#   'origin': 'South America',
#   'species': 'pubescens'},
#  {'heat': 'Extra Hot',
#   'jrp': '6 to 40',
#   'link': '<a href="http://www.pepperscale.com/malagueta-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '100000',
#   'min_shu': '50000',
#   'name': 'Malagueta Pepper',
#   'origin': 'Brazil',
#   'species': 'frutescens'},
#  {'heat': 'Extra Hot',
#   'jrp': '6 to 40',
#   'link': '<a href="http://www.pepperscale.com/chiltepin-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '100000',
#   'min_shu': '50000',
#   'name': 'Chiltepin Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '6 to 40',
#   'link': '<a href="http://www.pepperscale.com/thai-peppers" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '100000',
#   'min_shu': '50000',
#   'name': 'Thai Pepper',
#   'origin': 'Thailand',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '9 to 40',
#   'link': '<a href="http://www.pepperscale.com/charleston-hot-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '100000',
#   'min_shu': '70000',
#   'name': 'Charleston Hot Pepper',
#   'origin': 'USA',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '10 to 40',
#   'link': '<a href="https://www.pepperscale.com/siling-labuyo/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '100000',
#   'min_shu': '80000',
#   'name': 'Siling Labuyo',
#   'origin': 'Phillipines',
#   'species': 'frutescens'},
#  {'heat': 'Extra Hot',
#   'jrp': '6 to 40',
#   'link': '<a href="https://www.pepperscale.com/byadgi-chili/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '100000',
#   'min_shu': '50000',
#   'name': 'Byadgi Chili',
#   'origin': 'India',
#   'species': 'annuum'},
#  {'heat': 'Extra Hot',
#   'jrp': '12 to 120',
#   'link': '<a href="http://www.pepperscale.com/datil-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '300000',
#   'min_shu': '100000',
#   'name': 'Datil Pepper',
#   'origin': 'USA',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '15 to 130',
#   'link': '<a href="http://www.pepperscale.com/madame-jeanette-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '325000',
#   'min_shu': '125000',
#   'name': 'Madame Jeanette Pepper',
#   'origin': 'South America',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '16 to 130',
#   'link': '<a href="https://www.pepperscale.com/devils-tongue-pepper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '325000',
#   'min_shu': '125000',
#   'name': 'Devil\xe2\x80\x99s Tongue Pepper',
#   'origin': 'USA',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '12 to 140',
#   'link': '<a href="http://www.pepperscale.com/wiri-wiri-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '350000',
#   'min_shu': '100000',
#   'name': 'Wiri Wiri Pepper',
#   'origin': 'South America',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '12 to 140',
#   'link': '<a href="http://www.pepperscale.com/scotch-bonnet-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '350000',
#   'min_shu': '100000',
#   'name': 'Scotch Bonnet Pepper',
#   'origin': 'Caribbean',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '12 to 140',
#   'link': '<a href="http://www.pepperscale.com/habanero-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '350000',
#   'min_shu': '100000',
#   'name': 'Habanero Pepper',
#   'origin': 'South America',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '12 to 140',
#   'link': '<a href="http://www.pepperscale.com/peruvian-white-habanero" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '350000',
#   'min_shu': '100000',
#   'name': 'Peruvian White Habanero',
#   'origin': 'Peru',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '12 to 140',
#   'link': '<a href="http://www.pepperscale.com/goat-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '350000',
#   'min_shu': '100000',
#   'name': 'Goat Pepper',
#   'origin': 'Caribbean',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '18 to 140',
#   'link': '<a href="http://www.pepperscale.com/aji-chombo/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '350000',
#   'min_shu': '150000',
#   'name': 'Aji Chombo',
#   'origin': 'Panama',
#   'species': 'chinense'},
#  {'heat': 'Extra Hot',
#   'jrp': '14 to 160',
#   'link': '<a href="http://www.pepperscale.com/fatalii-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '400000',
#   'min_shu': '125000',
#   'name': 'Fatalii Pepper',
#   'origin': 'Africa',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '35 to 178',
#   'link': '<a href="http://www.pepperscale.com/caribbean-red-habanero" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '445000',
#   'min_shu': '300000',
#   'name': 'Caribbean Red Habanero',
#   'origin': 'Mexico',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '44 to 231',
#   'link': '<a href="http://www.pepperscale.com/red-savina-habanero" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '577000',
#   'min_shu': '350000',
#   'name': 'Red Savina Habanero',
#   'origin': 'USA',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '53 to 231',
#   'link': '<a href="http://www.pepperscale.com/chocolate-habanero" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '577000',
#   'min_shu': '425000',
#   'name': 'Chocolate Habanero',
#   'origin': 'Jamaica',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '106 to 400',
#   'link': '<a href="https://www.pepperscale.com/7-pot-bubblegum/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1000000',
#   'min_shu': '850000',
#   'name': '7 Pot Bubblegum',
#   'origin': 'United Kingdom',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '100 to 400',
#   'link': '<a href="http://www.pepperscale.com/bhut-jolokia-chocolate" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1001304',
#   'min_shu': '800000',
#   'name': 'Bhut Jolokia Chocolate',
#   'origin': 'India',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '107 to 417',
#   'link': '<a href="http://www.pepperscale.com/ghost-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1041427',
#   'min_shu': '855000',
#   'name': 'Ghost Pepper',
#   'origin': 'India',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '125 to 480',
#   'link': '<a href="https://www.pepperscale.com/7-pot-pepper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1200000',
#   'min_shu': '1000000',
#   'name': 'Trinidad 7 Pot Pepper',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '100 to 480',
#   'link': '<a href="https://www.pepperscale.com/7-pot-jonah/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1200000',
#   'min_shu': '800000',
#   'name': '7 Pot Jonah',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '133 to 500',
#   'link': '<a href="http://www.pepperscale.com/infinity-pepper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1250000',
#   'min_shu': '1067286',
#   'name': 'Infinity Pepper',
#   'origin': 'United Kingdom',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '100 to 507',
#   'link': '<a href="https://www.pepperscale.com/7-pot-primo/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1268250',
#   'min_shu': '800000',
#   'name': '7 Pot Primo',
#   'origin': 'United States',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '125 to 520',
#   'link': '<a href="https://www.pepperscale.com/7-pot-barrackpore/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1300000',
#   'min_shu': '1000000',
#   'name': '7 Pot Barrackpore',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '125 to 540',
#   'link': '<a href="https://www.pepperscale.com/7-pot-brain-strain/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1350000',
#   'min_shu': '1000000',
#   'name': '7 Pot Brain Strain',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '113 to 553',
#   'link': '<a href="https://www.pepperscale.com/naga-viper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1382118',
#   'min_shu': '900000',
#   'name': 'Naga Viper',
#   'origin': 'United Kingdom',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '100 to 585',
#   'link': '<a href="https://www.pepperscale.com/trinidad-scorpion-butch-t/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1463700',
#   'min_shu': '800000',
#   'name': 'Trinidad Scorpion \xe2\x80\x9cButch T\xe2\x80\x9d',
#   'origin': 'Australia',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '125 to 600',
#   'link': '<a href="http://www.pepperscale.com/naga-morich" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1500000',
#   'min_shu': '1000000',
#   'name': 'Naga Morich',
#   'origin': 'India',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '125 to 639',
#   'link': '<a href="http://www.pepperscale.com/dorset-naga" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1598227',
#   'min_shu': '1000000',
#   'name': 'Dorset Naga',
#   'origin': 'United Kingdom',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '109 to 742',
#   'link': '<a href="https://www.pepperscale.com/7-pot-douglah/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '1853986',
#   'min_shu': '923889',
#   'name': '7 Pot Douglah',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '150 to 800',
#   'link': '<a href="http://www.pepperscale.com/trinidad-moruga-scorpion" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '2000000',
#   'min_shu': '1200000',
#   'name': 'Trinidad Moruga Scorpion',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '150 to 800',
#   'link': '<a href="http://www.pepperscale.com/trinidad-scorpion-chocolate" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '2000000',
#   'min_shu': '1200000',
#   'name': 'Trinidad Scorpion Chocolate',
#   'origin': 'Trinidad',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '175 to 880',
#   'link': '<a href="http://www.pepperscale.com/carolina-reaper" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '2200000',
#   'min_shu': '1400000',
#   'name': 'Carolina Reaper',
#   'origin': 'USA',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '175 to 880',
#   'link': '<a href="https://www.pepperscale.com/komodo-dragon-pepper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '2200000',
#   'min_shu': '1400000',
#   'name': 'Komodo Dragon Pepper',
#   'origin': 'United Kingdom',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '310 to 992',
#   'link': '<a href="https://www.pepperscale.com/dragons-breath-pepper/" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '2480000',
#   'min_shu': '',
#   'name': 'Dragon\xe2\x80\x99s Breath Pepper',
#   'origin': 'United Kingdom',
#   'species': 'chinense'},
#  {'heat': 'Super Hot',
#   'jrp': '250 to 2,120',
#   'link': '<a href="http://www.pepperscale.com/pepper-spray" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '5300000',
#   'min_shu': '2000000',
#   'name': 'Pepper Spray',
#   'origin': 'N/A',
#   'species': 'N/A'},
#  {'heat': 'Super Hot',
#   'jrp': '1,875 to 6,400',
#   'link': '<a href="http://www.pepperscale.com/capsaicin" rel="noopener noreferrer" target="_blank">pepperscale.com</a>',
#   'max_shu': '16000000',
#   'min_shu': '15000000',
#   'name': 'Pure Capsaicin',
#   'origin': 'N/A',
#   'species': 'N/A'}]

# %% [markdown]
# ## Validate & sanitize data

# %%
peppers_data = pd.DataFrame(all_peppers)[INFO_LABELS]
peppers_data.head()

# %% [markdown]
# ### Names
#
# - Have to be unique

# %%
peppers_data["name"].nunique() == len(peppers_data)

# %% [markdown]
# ### Min/Max SHU (Scoville Heat Units)

# %%
# min/max currently strings
peppers_data["min_shu"].values[0]

# %%
(~peppers_data["min_shu"].str.isdigit()).sum()

# %%
def sanitize_shu(shu):
    """astype(errors="ignore") throwing NA error"""
    try:
        return int(shu)
    except:
        return None

# %%
peppers_data["min_shu"] = peppers_data["min_shu"].apply(sanitize_shu)
peppers_data["max_shu"] = peppers_data["max_shu"].apply(sanitize_shu)

# %%
peppers_data["min_shu"].plot.hist(bins=20)

# %%
peppers_data.boxplot("min_shu")

# %%
# huge jump in SHU - definitely some major outliers in the scale here
peppers_data[peppers_data["min_shu"] > 500000].sort_values("min_shu").head(10)

# %%
peppers_data["max_shu"].plot.hist(bins=20)

# %% [markdown]
# ### JRP (Jalapeño reference point)

# %% [markdown]
# #### Fix malformed JRP ranges

# %%
# malformed jrp ranges
peppers_data["jrp"].str.contains("to").sum(), len(peppers_data)

# %%
malformed_jrp = peppers_data[~peppers_data["jrp"].str.contains("to")]
malformed_jrp

# %%
def sanitize_jrp(jrp):
    jrp = jrp.replace("equal", "0")
    
    if jrp == "0":
        return [0,0]
    elif "to" not in jrp:
        return [int(val.replace(",", "")) for val in jrp.split(" - ")]
    return [int(val.replace(",", "")) for val in jrp.split(" to ")]


peppers_data[["min_jrp", "max_jrp"]] = pd.DataFrame(peppers_data["jrp"].apply(sanitize_jrp).values.tolist())
peppers_data.head()

# %% [markdown]
# ### Categoricals

# %% [markdown]
# #### Heat

# %%
peppers_data["heat"].value_counts(dropna=False)

# %%
# record needs to be sanitized -- but what heat is it?

peppers_data[peppers_data["heat"] == ""]

# %%
peppers_data[(peppers_data["min_shu"] >= 5000) & (peppers_data["max_shu"] <= 10000)]

# %%
peppers_data["heat"] = peppers_data["heat"].apply(lambda x: x if x != "" else "Medium")
peppers_data["heat"].value_counts()

# %% [markdown]
# #### Species

# %%
peppers_data["species"].value_counts()

# %%
peppers_data["species"] = peppers_data["species"].apply(lambda x: x if x != "N/A" else None)
peppers_data["species"].value_counts(dropna=False)

# %% [markdown]
# #### Origin

# %%
peppers_data["origin"].value_counts()

# %%
def sanitize_origin(origin):
    if pd.isnull(origin):
        return origin
    elif "Mexico" in origin and "South America" in origin:
        return "Mexico, South America"
    elif origin in ["USA", "United States"]:
        return "United States"
    elif origin not in ["N/A", "Unknown"]:
        return origin
    
peppers_data["origin"] = peppers_data["origin"].apply(sanitize_origin)
peppers_data["origin"].value_counts(dropna=False)

# %% [markdown]
# ##### Add region
#
# Regions from here: https://www.thoughtco.com/official-listing-of-countries-world-region-1435153

# %%
def add_region(origin):
    if origin in ["Italy", "United Kingdom", "Spain", "Hungary", "France"]:
        return "Europe"
    elif origin in ["United States", "Mexico"]:
        return "North America"
    elif origin in ["Trinidad", "Caribbean", "Jamaica",  "Panama", "Costa Rica"]:
        return "Central America and the Caribbean"
    elif origin in ["Peru", "Brazil", "Bolivia", "French Guyana", "South America"]:
        return "South America"
    elif origin in ["India", "Pakistan", "Thailand", "Japan", "China", "Phillipines"]:
        return "Asia"
    elif origin in ["Africa"]:
        return "Africa"
    elif origin in ["Australia"]:
        return "Australia and Oceania"
    elif origin in ["Syria"]:
        return "Middle East"
    elif pd.notnull(origin):
        return "Multi-Region"
    
peppers_data["region"] = peppers_data["origin"].apply(add_region)
peppers_data[["origin", "region"]].drop_duplicates()

# %% [markdown]
# ## Convert to JSON
#
# References:
# - https://json-ld.org/spec/latest/json-ld-api-best-practices/
# - https://www.sitepoint.com/google-maps-json-file/

# %%
JSON_COLS = ["name", "species", "heat", "region", "origin", "min_shu", "max_shu", "min_jrp", "max_jrp", "link"]
json_peppers_data = peppers_data[JSON_COLS]
json_peppers_data.head()

# %%
header_info = """{
    "source": "https://www.pepperscale.com/hot-pepper-list/",
    "contact": "https://github.com/alemosie",
    "last_updated": "%s",
    "peppers":
""" % (datetime.now())

with open ("data/peppers.json", "w") as json_file:
    json_file.write(header_info)
    json_file.write(json_peppers_data.to_json(orient='records'))
    json_file.write("}")

# %%
str(datetime.now().date()).replace("-","")

# %% [markdown]
# ## Class representation

# %%
class SanitizePepperData():
    """From nested object containing raw, solely parsed pepper data,
    create a clean dataset for analysis"""
    def __init__(self, pepper_data, write=False, output_path=None):
        self.raw = pd.DataFrame(pepper_data)

        clean_cols = ["name", "species", "heat", "region", "origin", "min_shu", "max_shu", "min_jrp", "max_jrp", "link"]
        self.clean = self.sanitize_pepper_data(self.raw.copy())[clean_cols]

        self.json = self.clean.to_dict(orient="records")
        if write:
            self.write_json(columns=clean_cols, output_path=output_path)

    #### GENERAL FUNCTIONS

    def sanitize_pepper_data(self, data):
        """Run all sanitization functions; produce clean copy of raw data"""
        data["min_shu"] = self.sanitize_shu("min_shu")
        data["max_shu"] = self.sanitize_shu("max_shu")
        data[["min_jrp", "max_jrp"]] = self.sanitize_jrp()
        data["heat"] = self.sanitize_heat()
        data["species"] = self.sanitize_species()
        data["origin"] = self.sanitize_field("origin", self.sanitize_origin_value)
        data["region"] = self.sanitize_field("origin", self.add_region_value)
        data["link"] = self.sanitize_link()
        return data

    def sanitize_field(self, field, value_sanitization_function):
        return self.raw[field].apply(value_sanitization_function)

    def write_json(self, output_path):
        header_info = """{
        "source": "https://www.pepperscale.com/hot-pepper-list/",
        "contact": "https://github.com/alemosie",
        "last_updated": "%s",
        "peppers":
        """ % (datetime.now())

        json_file = "data/peppers_{}.json".format(str(datetime.now().date()).replace("-","")) if not output_path else output_path
        print "Writing to %s..." % json_file
        with open (json_file, "w") as json_file:
            json_file.write(header_info)
            json_file.write(self.clean.to_json(orient='records'))
            json_file.write("}")

    #### FIELD FUNCTIONS

    ## Link

    def sanitize_link(self):
        return self.raw["link"].apply(lambda x: x.split('"')[1])

    ## Min/max SHU

    def sanitize_shu(self, shu_field):
        return self.raw[shu_field].apply(lambda x: int(x) if x != "" else None)

    ## JRP -> min/max JRP

    def sanitize_jrp_value(self, jrp):
        jrp = jrp.replace("equal", "0")

        if jrp == "0":
            return [0,0]
        elif "to" not in jrp:
            return [int(val.replace(",", "")) for val in jrp.split(" - ")]
        return [int(val.replace(",", "")) for val in jrp.split(" to ")]

    def sanitize_jrp(self):
        """creates dataframe with min and max JRP columns from raw JRP range"""
        return pd.DataFrame(self.raw["jrp"].apply(self.sanitize_jrp_value).values.tolist())

    ## Heat

    def sanitize_heat(self):
        return self.raw["heat"].apply(lambda x: x if x != "" else "Medium").str.lower()

    ## Species

    def sanitize_species(self):
        return self.raw["species"].apply(lambda x: x if x != "N/A" else None)

    ## Origin

    def sanitize_origin_value(self, origin):
        if pd.isnull(origin):
            return origin
        elif "Mexico" in origin and "South America" in origin:
            return "Mexico, South America"
        elif origin in ["USA", "United States"]:
            return "United States"
        elif origin not in ["N/A", "Unknown"]:
            return origin

    ## Region (new field to standardize origin)

    def add_region_value(self, origin):
        if origin in ["Italy", "United Kingdom", "Spain", "Hungary", "France"]:
            return "Europe"
        elif origin in ["United States", "Mexico"]:
            return "North America"
        elif origin in ["Trinidad", "Caribbean", "Jamaica",  "Panama", "Costa Rica"]:
            return "Central America and the Caribbean"
        elif origin in ["Peru", "Brazil", "Bolivia", "French Guyana", "South America"]:
            return "South America"
        elif origin in ["India", "Pakistan", "Thailand", "Japan", "China", "Phillipines"]:
            return "Asia"
        elif origin in ["Africa"]:
            return "Africa"
        elif origin in ["Australia"]:
            return "Australia and Oceania"
        elif origin in ["Syria"]:
            return "Middle East"
        elif pd.notnull(origin):
            return "Multi-Region"

# %%
SanitizePepperData(all_peppers).clean
# Out:
#                             name   species       heat  \
# 0                    Bell Pepper    annuum       mild
# 1                   Gypsy Pepper    annuum       mild
# 2           Purple Beauty Pepper    annuum       mild
# 3                 Melrose Pepper    annuum       mild
# 4             Peperone Di Senise    annuum       mild
# 5       California Wonder Pepper    annuum       mild
# 6                  Carmen Pepper    annuum       mild
# 7         Tangerine Dream Pepper    annuum       mild
# 8                Shishito Pepper    annuum       mild
# 9                 Banana Pepper     annuum       mild
# 10                  Pepperoncini    annuum       mild
# 11                Pimento Pepper    annuum       mild
# 12              Trinidad Perfume  chinense       mild
# 13        Santa Fe Grande Pepper    annuum       mild
# 14              Holy Mole Pepper    annuum       mild
# 15                 Medusa Pepper    annuum       mild
# 16       Italian Long Hot Pepper    annuum       mild
# 17              Cubanelle Pepper    annuum       mild
# 18              Piquillo Peppers    annuum       mild
# 19             Beaver Dam Pepper    annuum       mild
# 20                     Aji Dulce  chinense       mild
# 21                  Chilly Chili    annuum       mild
# 22               Mexibell Pepper    annuum       mild
# 23               Peppadew Pepper  baccatum       mild
# 24                     Aji Panca  baccatum       mild
# 25                  Ancho Pepper    annuum       mild
# 26                Poblano Pepper    annuum       mild
# 27              Guindilla Pepper    annuum       mild
# 28                Kashmiri Chili    annuum       mild
# 29                 Padrón Pepper    annuum       mild
# ..                           ...       ...        ...
# 92          Scotch Bonnet Pepper  chinense  extra hot
# 93               Habanero Pepper  chinense  extra hot
# 94       Peruvian White Habanero  chinense  extra hot
# 95                   Goat Pepper  chinense  extra hot
# 96                    Aji Chombo  chinense  extra hot
# 97                Fatalii Pepper  chinense  extra hot
# 98        Caribbean Red Habanero  chinense  super hot
# 99           Red Savina Habanero  chinense  super hot
# 100           Chocolate Habanero  chinense  super hot
# 101              7 Pot Bubblegum  chinense  super hot
# 102       Bhut Jolokia Chocolate  chinense  super hot
# 103                 Ghost Pepper  chinense  super hot
# 104        Trinidad 7 Pot Pepper  chinense  super hot
# 105                  7 Pot Jonah  chinense  super hot
# 106              Infinity Pepper  chinense  super hot
# 107                  7 Pot Primo  chinense  super hot
# 108            7 Pot Barrackpore  chinense  super hot
# 109           7 Pot Brain Strain  chinense  super hot
# 110                   Naga Viper  chinense  super hot
# 111  Trinidad Scorpion “Butch T”  chinense  super hot
# 112                  Naga Morich  chinense  super hot
# 113                  Dorset Naga  chinense  super hot
# 114                7 Pot Douglah  chinense  super hot
# 115     Trinidad Moruga Scorpion  chinense  super hot
# 116  Trinidad Scorpion Chocolate  chinense  super hot
# 117              Carolina Reaper  chinense  super hot
# 118         Komodo Dragon Pepper  chinense  super hot
# 119       Dragon’s Breath Pepper  chinense  super hot
# 120                 Pepper Spray      None  super hot
# 121               Pure Capsaicin      None  super hot
#
#                                 region                 origin     min_shu  \
# 0                         Multi-Region  Mexico, South America         0.0
# 1                         Multi-Region          United States         0.0
# 2                        South America          South America         0.0
# 3                         Multi-Region          United States         0.0
# 4                               Europe                  Italy         0.0
# 5                        North America          United States         0.0
# 6                               Europe                  Italy         0.0
# 7                         Multi-Region          United States         0.0
# 8                                 Asia                  Japan        50.0
# 9                        South America          South America         0.0
# 10                              Europe                  Italy       100.0
# 11                        Multi-Region                   None       100.0
# 12   Central America and the Caribbean              Caribbean         0.0
# 13                       North America          United States       500.0
# 14                        Multi-Region          United States       700.0
# 15                        Multi-Region  Mexico, South America         1.0
# 16                              Europe                  Italy       100.0
# 17                        Multi-Region            Italy, Cuba       100.0
# 18                              Europe                  Spain       500.0
# 19                        Multi-Region          United States       500.0
# 20   Central America and the Caribbean              Caribbean         0.0
# 21                        Multi-Region          United States         1.0
# 22                       North America          United States       100.0
# 23                              Africa                 Africa      1100.0
# 24                       South America                   Peru      1000.0
# 25                       North America                 Mexico      1000.0
# 26                       North America                 Mexico      1000.0
# 27                              Europe                  Spain      1000.0
# 28                                Asia                  India      1000.0
# 29                              Europe                  Spain       500.0
# ..                                 ...                    ...         ...
# 92   Central America and the Caribbean              Caribbean    100000.0
# 93                       South America          South America    100000.0
# 94                       South America                   Peru    100000.0
# 95   Central America and the Caribbean              Caribbean    100000.0
# 96   Central America and the Caribbean                 Panama    150000.0
# 97                              Africa                 Africa    125000.0
# 98                       North America                 Mexico    300000.0
# 99                        Multi-Region          United States    350000.0
# 100  Central America and the Caribbean                Jamaica    425000.0
# 101                             Europe         United Kingdom    850000.0
# 102                               Asia                  India    800000.0
# 103                               Asia                  India    855000.0
# 104  Central America and the Caribbean               Trinidad   1000000.0
# 105  Central America and the Caribbean               Trinidad    800000.0
# 106                             Europe         United Kingdom   1067286.0
# 107                      North America          United States    800000.0
# 108  Central America and the Caribbean               Trinidad   1000000.0
# 109  Central America and the Caribbean               Trinidad   1000000.0
# 110                             Europe         United Kingdom    900000.0
# 111              Australia and Oceania              Australia    800000.0
# 112                               Asia                  India   1000000.0
# 113                             Europe         United Kingdom   1000000.0
# 114  Central America and the Caribbean               Trinidad    923889.0
# 115  Central America and the Caribbean               Trinidad   1200000.0
# 116  Central America and the Caribbean               Trinidad   1200000.0
# 117                       Multi-Region          United States   1400000.0
# 118                             Europe         United Kingdom   1400000.0
# 119                             Europe         United Kingdom         NaN
# 120                       Multi-Region                   None   2000000.0
# 121                       Multi-Region                   None  15000000.0
#
#       max_shu  min_jrp  max_jrp  \
# 0           0    -8000    -2500
# 1           0    -8000    -2500
# 2           0    -8000    -2500
# 3           0    -8000    -2500
# 4           0    -8000     2500
# 5           0    -2500    -8000
# 6           0    -2500    -8000
# 7         100    -8000     -250
# 8         200     -160      -13
# 9         500    -8000       -5
# 10        500      -80       -5
# 11        500      -80       -5
# 12        500    -8000       -5
# 13        700       -3      -16
# 14        800      -10       -3
# 15       1000    -8000       -3
# 16       1000      -80       -3
# 17       1000      -80       -3
# 18       1000      -16       -3
# 19       1000      -16       -3
# 20       1000    -8000       -3
# 21       1000    -8000       -2
# 22       1000       -3      -80
# 23       1200       -7       -2
# 24       1500       -8       -2
# 25       1500       -8       -2
# 26       1500       -8       -2
# 27       2000       -8        0
# 28       2000       -8        0
# 29       2500      -16        0
# ..        ...      ...      ...
# 92     350000       12      140
# 93     350000       12      140
# 94     350000       12      140
# 95     350000       12      140
# 96     350000       18      140
# 97     400000       14      160
# 98     445000       35      178
# 99     577000       44      231
# 100    577000       53      231
# 101   1000000      106      400
# 102   1001304      100      400
# 103   1041427      107      417
# 104   1200000      125      480
# 105   1200000      100      480
# 106   1250000      133      500
# 107   1268250      100      507
# 108   1300000      125      520
# 109   1350000      125      540
# 110   1382118      113      553
# 111   1463700      100      585
# 112   1500000      125      600
# 113   1598227      125      639
# 114   1853986      109      742
# 115   2000000      150      800
# 116   2000000      150      800
# 117   2200000      175      880
# 118   2200000      175      880
# 119   2480000      310      992
# 120   5300000      250     2120
# 121  16000000     1875     6400
#
#                                                   link
# 0               http://www.pepperscale.com/bell-pepper
# 1              http://www.pepperscale.com/gypsy-pepper
# 2      http://www.pepperscale.com/purple-beauty-pepper
# 3            http://www.pepperscale.com/melrose-pepper
# 4       http://www.pepperscale.com/peperone-di-senise/
# 5    https://www.pepperscale.com/california-wonder-...
# 6           https://www.pepperscale.com/carmen-pepper/
# 7    https://www.pepperscale.com/tangerine-dream-pe...
# 8           http://www.pepperscale.com/shishito-pepper
# 9             http://www.pepperscale.com/banana-pepper
# 10             http://www.pepperscale.com/pepperoncini
# 11           http://www.pepperscale.com/pimento-pepper
# 12        http://www.pepperscale.com/trinidad-perfume/
# 13   https://www.pepperscale.com/santa-fe-grande-pe...
# 14         http://www.pepperscale.com/holy-mole-pepper
# 15            http://www.pepperscale.com/medusa-pepper
# 16   http://www.pepperscale.com/italian-long-hot-pe...
# 17         http://www.pepperscale.com/cubanelle-pepper
# 18         http://www.pepperscale.com/piquillo-peppers
# 19        http://www.pepperscale.com/beaver-dam-pepper
# 20               http://www.pepperscale.com/aji-dulce/
# 21           https://www.pepperscale.com/chilly-chili/
# 22        https://www.pepperscale.com/mexibell-pepper/
# 23          http://www.pepperscale.com/peppadew-pepper
# 24                http://www.pepperscale.com/aji-panca
# 25             http://www.pepperscale.com/ancho-pepper
# 26          http://www.pepperscale.com/poblano-peppers
# 27         http://www.pepperscale.com/guindilla-pepper
# 28         https://www.pepperscale.com/kashmiri-chili/
# 29            http://www.pepperscale.com/padron-pepper
# ..                                                 ...
# 92     http://www.pepperscale.com/scotch-bonnet-pepper
# 93          http://www.pepperscale.com/habanero-pepper
# 94   http://www.pepperscale.com/peruvian-white-haba...
# 95              http://www.pepperscale.com/goat-pepper
# 96              http://www.pepperscale.com/aji-chombo/
# 97           http://www.pepperscale.com/fatalii-pepper
# 98   http://www.pepperscale.com/caribbean-red-habanero
# 99      http://www.pepperscale.com/red-savina-habanero
# 100      http://www.pepperscale.com/chocolate-habanero
# 101       https://www.pepperscale.com/7-pot-bubblegum/
# 102  http://www.pepperscale.com/bhut-jolokia-chocolate
# 103            http://www.pepperscale.com/ghost-pepper
# 104          https://www.pepperscale.com/7-pot-pepper/
# 105           https://www.pepperscale.com/7-pot-jonah/
# 106         http://www.pepperscale.com/infinity-pepper
# 107           https://www.pepperscale.com/7-pot-primo/
# 108     https://www.pepperscale.com/7-pot-barrackpore/
# 109    https://www.pepperscale.com/7-pot-brain-strain/
# 110            https://www.pepperscale.com/naga-viper/
# 111  https://www.pepperscale.com/trinidad-scorpion-...
# 112             http://www.pepperscale.com/naga-morich
# 113             http://www.pepperscale.com/dorset-naga
# 114         https://www.pepperscale.com/7-pot-douglah/
# 115  http://www.pepperscale.com/trinidad-moruga-sco...
# 116  http://www.pepperscale.com/trinidad-scorpion-c...
# 117         http://www.pepperscale.com/carolina-reaper
# 118  https://www.pepperscale.com/komodo-dragon-pepper/
# 119  https://www.pepperscale.com/dragons-breath-pep...
# 120            http://www.pepperscale.com/pepper-spray
# 121               http://www.pepperscale.com/capsaicin
#
# [122 rows x 10 columns]
