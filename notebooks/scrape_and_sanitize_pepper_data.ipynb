# %%
import pandas as pd
import re
from fuzzywuzzy import fuzz
import json
from datetime import datetime
from bs4 import BeautifulSoup
import urllib
import pdb
import ssl

from selenium import webdriver

import matplotlib.pyplot as plt
# %matplotlib inline

SCHEMA =  [
    "name", "species", "heat", "region", "origin", "min_shu", "max_shu",
    "min_jrp", "max_jrp", "link", "source_name"
]

# %%
with open('../data/pepperscale_20171028.json') as json_data:
    data = json.load(json_data)
pepperscale = pd.DataFrame(data["peppers"])
pepperscale.sample(3)

# %% [markdown]
# # Shared functions

# %%
def get_page_html(url, expired_cert=False):
    headers = {
                "user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36(KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36"
            }

    request = urllib.request.Request(url, 
                                     headers=headers)
    if not expired_cert:
        return BeautifulSoup(urllib.request.urlopen(request).read().decode('utf-8'), 'html.parser')
    context = ssl._create_unverified_context()
    return BeautifulSoup(urllib.request.urlopen(request, context=context).read().decode('utf-8'), 'html.parser')

def process_row(row, source_name, schema=["name", "max_shu", "link", "source_name"]):
    row_url = cd_url if not row.find("a") else row.find("a")["href"]
    row_data = [col.text for col in row.find_all("td")] + [row_url] + [source_name]
    row_data[1] = int(row_data[1].replace(",", ""))
    return dict(zip(schema, row_data))

# %% [markdown]
# # Chiliworld

# %%
chiliworld_url = "https://www.chilliworld.com/factfile/scoville-scale#ChilliPepperScovilleScale"
chiliworld_html = get_page_html(chiliworld_url)
len(chiliworld_html.find(id="ChilliPepperScovilleScale").find_all("tr"))

# %%
def compare_pepper_to_pepperscale(pepper):
    possibilities = []
    for pepperscale_pepper in pepperscale["name"].str.lower().str.replace("pepper", "").str.replace("chile ", ""):
        if fuzz.ratio(pepper, pepperscale_pepper) > 70:
            possibilities.append(pepperscale_pepper)
    return possibilities

def sanitize_name(name):
    if "<b>" not in str(name):
        pepper_name = name.split("(")[0].split(",")[0]
        sanitized_pepper_name = pepper_name.lower().replace(" pepper", "").replace("the ", "")
        return " ".join([part.strip().capitalize() for part in sanitized_pepper_name.split()])
    
def sanitize_shu(shu):
    return [int(val) for val in shu.replace(" (reported) ", "").replace(",", "").split(" - ")]

def sanitize_location(name):
    if name and "<b>" not in str(name):
        location = name.split("(")[1] if len(name.split("(")) > 1 else None
        if location and ("Wales" in location or "England" in location):
            return "United Kingdom"
        elif location and "South Carolina" in location:
            return "United States"
        elif location and "Australia" in location:
            return "Australia"
        return None

def process_chiliworld_peppers(write=False):
    peppers = []
    
    for row in chiliworld_html.find(id="ChilliPepperScovilleScale").find_all("tr"):
        raw_shu, raw_name = [element.contents[0] for element in row.find_all("td")]
        name = sanitize_name(raw_name)
        if name: # manual discard of sweet bell, since bell pepper in pepperscale
            name = name + " Pepper"
            location = sanitize_location(raw_name)
            shu = sanitize_shu(raw_shu)
            min_shu, max_shu = shu if len(shu) > 1 else [None, shu[0]]
            source = "ChiliWorld"
            link = "https://www.chilliworld.com/factfile/scoville-scale#ChilliPepperScovilleScale"
            peppers.append([name, link, min_shu, max_shu, location])
            
    labels = ["name", "link", "min_shu", "max_shu", "origin"]
    peppers = pd.DataFrame(peppers, columns=labels)
        
def process_chiliworld_peppers_compare(write=False):
    new_peppers = []
    for row in chiliworld_html.find(id="ChilliPepperScovilleScale").find_all("tr"):
        raw_shu, raw_name = [element.contents[0] for element in row.find_all("td")]
        name = sanitize_name(raw_name)
        if name and name != "Sweet Bell": # manual discard of sweet bell, since bell pepper in pepperscale
            if len(compare_pepper_to_pepperscale(name)) == 0:
                name = name + " Pepper"
                location = sanitize_location(raw_name)
                shu = sanitize_shu(raw_shu)
                min_shu, max_shu = shu if len(shu) > 1 else [None, shu[0]]
                source = "ChiliWorld"
                link = "https://www.chilliworld.com/factfile/scoville-scale#ChilliPepperScovilleScale"
                new_peppers.append([name, link, min_shu, max_shu, None, None, None, None, location])
    labels = ["name", "link", "min_shu", "max_shu", "min_jrp", "max_jrp", "heat", "species", "origin"]
    new_peppers = pd.DataFrame(new_peppers, columns=labels)
    if write:
        file_name = "{}/chiliworld_{}.csv".format("../data/", str(datetime.now().date()).replace("-",""))
        new_peppers.to_csv(file_name, index=False)

# %%
process_chiliworld_peppers(write=True)

# %% [markdown]
# # Pepperheads

# %%
ph_url = "https://pepperheadsforlife.com/the-scoville-scale/"
ph_html = get_page_html(ph_url, expired_cert=True)
ph_rows = ph_html.find("tbody").find_all("tr")
len(ph_rows)
# Out:
# 463

# %%
ph_data = [process_row(row, "Pepperheads") for row in ph_rows]
ph_data
# Out:
# [{'link': 'http://pepperheadsforlife.com/resiniferatoxin/',
#   'max_shu': 16000000000,
#   'name': 'Resiniferatoxin',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/extract-scale/tinyatoxin/',
#   'max_shu': 5300000000,
#   'name': 'Tinyatoxin',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/pure-capsaicin-16000000-scoville-units/',
#   'max_shu': 16000000,
#   'name': 'Pure Capsaicin',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/extract-scale/dihydrocapsaicin/',
#   'max_shu': 15000000,
#   'name': 'Dihydrocapsaicin',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/extract-scale/nonivamide/',
#   'max_shu': 9200000,
#   'name': 'Nonivamide',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/nordihydrocapsaicin/',
#   'max_shu': 9100000,
#   'name': 'Nordihydrocapsaicin',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/pepper-extract-scale/homodihydrocapsaicin/',
#   'max_shu': 8600000,
#   'name': 'Homodihydrocapsaicin',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/pepper-extract-scale/police-grade-pepper-spray/',
#   'max_shu': 5300000,
#   'name': 'Police Grade Pepper Spray',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/carolina-reaper-scoville-heat-units/',
#   'max_shu': 2200000,
#   'name': 'Carolina Reaper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/pepper-extract-scale/common-pepper-spray/',
#   'max_shu': 2000000,
#   'name': 'Common Pepper Spray',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2009231,
#   'name': 'Trinidad Moruga Scorpion',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/7-pot-douglah/',
#   'max_shu': 1853396,
#   'name': '7 Pot Douglah',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/trinidad-scorpion-pepper-scoville-units/',
#   'max_shu': 1463700,
#   'name': 'Trinidad Scorpion Butch T',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/naga-viper-pepper/',
#   'max_shu': 1382118,
#   'name': 'Naga Viper Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/7-pot-barrackpore/',
#   'max_shu': 1300000,
#   'name': '7 Pot Barrackpore',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1200000,
#   'name': '7 Pot Jonah',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/7-pot-primo/',
#   'max_shu': 1200000,
#   'name': '7 Pot Primo',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/new-mexico-scorpion-pepper-2/',
#   'max_shu': 1191595,
#   'name': 'New Mexico Scorpion',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/infinity-chili/',
#   'max_shu': 1176182,
#   'name': 'Infinity Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/bedfordshire-super-naga-chili/',
#   'max_shu': 1120000,
#   'name': 'Bedfordshire Super Naga Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/dorset-naga-pepper/',
#   'max_shu': 1100000,
#   'name': 'Dorset Naga Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/naga-jolokia-pepper/',
#   'max_shu': 1100000,
#   'name': 'Naga Jolokia',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/naga-morich-pepper/',
#   'max_shu': 1100000,
#   'name': 'Naga Morich',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/spanish-naga-chili/',
#   'max_shu': 1086844,
#   'name': 'Spanish Naga Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/7-pot-madballz/',
#   'max_shu': 1066882,
#   'name': '7 Pot Madballz',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/bhut-jolokia-pepper-ghost-pepper-scoville-units/',
#   'max_shu': 1041427,
#   'name': 'Bhut Jolokia Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/chocolate-bhut-jolokia/',
#   'max_shu': 1001304,
#   'name': 'Chocolate Bhut Jolokia',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/7-pot-brain-strain/',
#   'max_shu': 1000000,
#   'name': '7 Pot Brain Strain',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/bhut-jolokia-indian-carbon/',
#   'max_shu': 1000000,
#   'name': 'Bhut Jolokia Indian Carbon',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/trinidad-scorpion-pepper-scoville-units/',
#   'max_shu': 1000000,
#   'name': 'Trinidad Scorpion',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 900000,
#   'name': 'Raja Mirch',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/habanaga-pepper/',
#   'max_shu': 800000,
#   'name': 'Habanaga Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/nagabon-chili/',
#   'max_shu': 800000,
#   'name': 'Nagabon Jolokia',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/red-savina-habanero/',
#   'max_shu': 580000,
#   'name': 'Red Savina Habanero',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/fatalii-pepper/',
#   'max_shu': 500000,
#   'name': 'Fatalii',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500000,
#   'name': 'Aji Chombo',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500000,
#   'name': 'Pingo de Ouro',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 470000,
#   'name': 'Aribibi Gusano',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/caribbean-red-habanero/',
#   'max_shu': 400000,
#   'name': 'Caribbean Red Habanero',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/chocolate-habanero-peppers/',
#   'max_shu': 350000,
#   'name': 'Chocolate Habanero',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/datil-pepper/',
#   'max_shu': 350000,
#   'name': 'Datil Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/habanero-peppers/',
#   'max_shu': 350000,
#   'name': 'Habanero',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 350000,
#   'name': 'Jamaican Hot Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/madame-jeanette/',
#   'max_shu': 350000,
#   'name': 'Madame Jeanette chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/rocoto-peppers/',
#   'max_shu': 350000,
#   'name': 'Rocoto Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/scotch-bonnet-scoville-units/',
#   'max_shu': 350000,
#   'name': 'Scotch Bonnet',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/zimbabwe-bird-chili/',
#   'max_shu': 350000,
#   'name': 'Zimbabwe Bird Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/adjuma-pepper/',
#   'max_shu': 350000,
#   'name': 'Adjuma',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/guyana-wiri-wiri/',
#   'max_shu': 350000,
#   'name': 'Guyana Wiri Wiri',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/tiger-paw-pepper/',
#   'max_shu': 348634,
#   'name': 'Tiger Paw',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/big-sun-habanero/',
#   'max_shu': 325000,
#   'name': 'Big Sun Habanero',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/mustard-habanero/',
#   'max_shu': 300000,
#   'name': 'Mustard Habanero',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/devils-tongue-pepper/',
#   'max_shu': 300000,
#   'name': 'Devil’s Tongue',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/orange-rocoto-pepper/',
#   'max_shu': 300000,
#   'name': 'Orange Rocoto Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 300000,
#   'name': 'Paper Lantern Habanero',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 300000,
#   'name': 'Piri Piri',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 300000,
#   'name': 'Red Cheese',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 300000,
#   'name': 'Red Rocoto',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/tepin-pepper/',
#   'max_shu': 300000,
#   'name': 'Tepin Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 300000,
#   'name': 'Thai Burapa',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 300000,
#   'name': 'White Habanero',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 300000,
#   'name': 'Yellow Habanero',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 265000,
#   'name': 'Texas Chiltepin',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 250000,
#   'name': 'Pimenta de Neyde',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 240000,
#   'name': 'Maori',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 240000,
#   'name': 'Quintisho',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 225000,
#   'name': 'Bird’s Eye Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 186000,
#   'name': 'Ecuador Hot',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/pepper-extract-scale/shogaol/',
#   'max_shu': 160000,
#   'name': 'Shogaol',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/sparkler-pepper/',
#   'max_shu': 160000,
#   'name': 'Sparkler',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 150000,
#   'name': 'Jamaican Gold',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 150000,
#   'name': 'Cajamarca',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 150000,
#   'name': 'Kumataka',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 150000,
#   'name': 'Orange Thai',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 150000,
#   'name': 'Red Thai',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 150000,
#   'name': 'Thai Dragon',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 150000,
#   'name': 'Yellow Thai',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/carolina-cayenne-pepper-scoville-units/',
#   'max_shu': 125000,
#   'name': 'Carolina Cayenne',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/tabiche-pepper-scoville-units-shu/',
#   'max_shu': 115000,
#   'name': 'Tabiche Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/scoville-units-bahamian-pepper/',
#   'max_shu': 110000,
#   'name': 'Bahamian Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 108000,
#   'name': 'Aji Cito',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Piperine',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/birds-eye-pepper-scoville-units/',
#   'max_shu': 100000,
#   'name': 'African Birds Eye Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/byadgi-peppers/',
#   'max_shu': 100000,
#   'name': 'Byadgi Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'China Express Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Diablo Grande',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Malagueta',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Pepin Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/aji-charapita/',
#   'max_shu': 100000,
#   'name': 'Aji Charapita',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Ají Lemon Drop',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Ají Rojo Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Black Scorpion Tongue',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/charleston-hot-chili/',
#   'max_shu': 100000,
#   'name': 'Charleston Hot Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/chiltepin-pepper-scoville-units-shu/',
#   'max_shu': 100000,
#   'name': 'Chiltepin Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Cili Goronong',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Firecracker Pequin Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Indian Jwala Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Mayan Cobanero Love Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Peri-Peri Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Siling Labuyo Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/thai-pepper-scoville-units-shu/',
#   'max_shu': 100000,
#   'name': 'Thai Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 85000,
#   'name': 'Golden Cayenne Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 81400,
#   'name': 'Suryaki Cluster',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 80000,
#   'name': 'Haimen',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/red-amazon-pepper/',
#   'max_shu': 75000,
#   'name': 'Red Amazon',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 75000,
#   'name': 'Tien Tsin Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 75000,
#   'name': 'Yatsafusa',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 70000,
#   'name': 'Chi Chien Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 70000,
#   'name': 'Prik Kee Noo',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/pepper-extract-scale/gingerol/',
#   'max_shu': 60000,
#   'name': 'Gingerol',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/pequin-pepper-scoville-units-shu-3/',
#   'max_shu': 58000,
#   'name': 'Pequin Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 58000,
#   'name': 'Piquin',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 57000,
#   'name': 'African Pequin',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 55000,
#   'name': 'Chile Grande Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/aji-limo-pepper/',
#   'max_shu': 50000,
#   'name': 'Aji Limo',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Aci Sivri Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Aji Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Balloon Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Brazilian Starfish pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/cumari-pepper/',
#   'max_shu': 50000,
#   'name': 'Cumari Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Guntur Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Satans Kiss Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Tricolor variegata Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Wild Baccatum',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/aji-amarillo-pepper/',
#   'max_shu': 50000,
#   'name': 'Aji Amarillo',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Ají Crystal Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Ají Omnicolor Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Akabare',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/aurora-pepper/',
#   'max_shu': 50000,
#   'name': 'Aurora',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Bishops Crown Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Black Cuban Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Bolivian Rainbow Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Bonney',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/cayenne-pepper-scoville-units-shu/',
#   'max_shu': 50000,
#   'name': 'Cayenne Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Chinese Five Color Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Coban',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Demre',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Desi Teekhi',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Diente de Perro',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'DKurnool',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Dong Xuan Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Dunso',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Etna',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Explosive Ember Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Faria',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Fiji',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Filius Blue Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Fluorescent Purple Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Goat Horn Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Guarani',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Hermosillo',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Hot Portugal Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Inca Berry Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Kurnool Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Large Purple Cayenne Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Large Red Thick Cayenne Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Little Nubian Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Maras Biber',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Marbles Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'McMahon’s Texas Bird Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Medusa’s Head Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'NuMex Twilight Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Orange Manzano Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Punjab',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Purple Prince',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Pusa Jwala',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Rain Forest Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Red Manzano Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Red Squash Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Rooster Spur Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/santaka-pepper-scoville-units-shu/',
#   'max_shu': 50000,
#   'name': 'Santaka Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Siling Haba Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/scoville-units-super-chili-pepper/',
#   'max_shu': 50000,
#   'name': 'Super Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/tabasco-pepper-scoville-units/',
#   'max_shu': 50000,
#   'name': 'Tabasco Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Urfa Biber',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Yellow Manzano Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 45000,
#   'name': 'Long Slim Cayenne Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 42600,
#   'name': 'Beni Highland',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 40000,
#   'name': 'Dundicut',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 40000,
#   'name': 'Guntur Sannam Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/de-arbol-pepper-scoville-units/',
#   'max_shu': 30000,
#   'name': 'Chile de Arbol',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Japones Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Abchazskij Ostruyi',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Afega Longa',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Aji Carmine',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Aji Criolla Sella',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Ata Barukono',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Australian Latern',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Berbere',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Beslers Cherry',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Black Pearl',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Black Prince',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Bode Amarela',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Bombilla Amarilla',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Bonanza Brasileira',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Bubba',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Cabai Burong',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Cabai Merah Besar',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Caballero',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chao Tian Jiao',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/pico-de-pajaro/',
#   'max_shu': 30000,
#   'name': 'Pico de Pajaro',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chile Inayague',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chile Maya',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chile Pepe',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chilito de Simojovel',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chinchi Uchu',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chivato',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chupetinho',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'De árbol Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Dedo de Bahamas',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Dieng Plateau',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Erva de Bode',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Golden Heat',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Hahony Kacho',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Havaiana',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Holiday Cheer',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Inca Glow',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Inca Laranja',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Inca Red Drop',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Jwala',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Kim Chi',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Lemon Drop',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Little Elf',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/manzano-pepper-scoville-units/',
#   'max_shu': 30000,
#   'name': 'Manzano',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Merah',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'New Delhi Long',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Onza Yellow',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Orozco',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Peter Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Pimenta de Bode',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Royal Black',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Shipkas',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Takanotsume',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 27000,
#   'name': 'Stumpy',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 26500,
#   'name': 'Gambia',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 25000,
#   'name': 'Tianying',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 23600,
#   'name': 'Tears Of Fire',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 23000,
#   'name': 'Aleppo Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 23000,
#   'name': 'Chili Wili Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 23000,
#   'name': 'Halabi Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 23000,
#   'name': 'Serrano Huasteco Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/scoville-units-serrano-pepper/',
#   'max_shu': 23000,
#   'name': 'Serrano Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 20000,
#   'name': 'Aji Colorado Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 20000,
#   'name': 'Black Hungarian Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 20000,
#   'name': 'Ají Brazilian Pumpkin Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 20000,
#   'name': 'Ají Pineapple Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 20000,
#   'name': 'Onza Roja Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 20000,
#   'name': 'Peruvian Purple Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 17000,
#   'name': 'Aji Escabeche',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 17000,
#   'name': 'Hidalgo Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/pepper-extract-scale/capsiate/',
#   'max_shu': 16000,
#   'name': 'Capsiate',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15500,
#   'name': 'Aji Bento',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Yellow Wax Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Abbraccio',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Afegã Curta',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Aji Cobincho',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Balãozinho',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Cseresznye Paprika',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Dutch Red',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Estrela-do-Mar',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Hot Banana Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Israeli Hot',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Jarales',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 12000,
#   'name': 'Costeno Rojo Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 12000,
#   'name': 'Kung Pao Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Louisiana Hot Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Pasilla de Oaxaco Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Biker Billy Jalapeno',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Dutch Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Earbob',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Fish Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Fresno Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Hot Apple Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/hot-wax-pepper-scoville-units/',
#   'max_shu': 10000,
#   'name': 'Hungarian Wax Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/jalapeno-pepper-scoville-units/',
#   'max_shu': 10000,
#   'name': 'Jalapeño Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Lumbre Hot',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Puya Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 9000,
#   'name': 'Purple Tiger ‘Trifetti’',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 8500,
#   'name': 'Long Thick Cayenne',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 8000,
#   'name': 'Chile Gordo Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/guajillo-pepper-scoville-heat-units/',
#   'max_shu': 8000,
#   'name': 'Guajillo Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 8000,
#   'name': 'Huachinango Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 8000,
#   'name': 'Mitla Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 8000,
#   'name': 'New Mexican Annaheim Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 8000,
#   'name': 'Cascabel Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/chipotle-pepper-scoville-heat-units-shu/',
#   'max_shu': 8000,
#   'name': 'Chipotle Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 8000,
#   'name': 'Pretty Purple',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 7000,
#   'name': 'Sandia Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 7000,
#   'name': 'Barker’s Hot',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 6000,
#   'name': 'Chimayo',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 6000,
#   'name': 'Hatch Green',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Cherry Bomb Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Chilcostle Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Huasteco Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Inferno Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Serrano Tampequino Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Volcano Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Atomic Heart',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Azr',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Baccio di Satana',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Bermuda',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Bouquet',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Bulgarian Carrot Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Caloro Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Cenoura Búlgara',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Cereja',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Chile de Cuscutlan',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Chintexle',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Cochabamba',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Cochiti',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Cyklon',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Dhanraj',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Equador Roxa',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Floral Gem',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Fogo Explosivo',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Goan',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Golden Nugget',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Gulbarga',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Hari Mirch',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Huatulco Puntado',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Inca',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Inchanga',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Isleta',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Jaloro Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Jemes',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Kalia',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Kerinting',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Kori Sitakame',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
# ...
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2500,
#   'name': 'Alcalde',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2500,
#   'name': 'Ammazzo',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/anaheim-pepper-scoville-heat-units/',
#   'max_shu': 2500,
#   'name': 'Anaheim Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2500,
#   'name': 'Calabria',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2500,
#   'name': 'Japanese Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/new-mex-big-jim-pepper/',
#   'max_shu': 2500,
#   'name': 'NuMex Big JimPepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/rocotilla-pepper-scoville-units/',
#   'max_shu': 2500,
#   'name': 'Rocotilla Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Chilhuacle Negro Chile',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Costeno Amarillo Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Szentesi Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/ancho-pepper-scoville-units/',
#   'max_shu': 2000,
#   'name': 'Ancho Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Chilaca Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Espanola Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Hawaiian Sweet Hot Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Mulato Isleno Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/pasilla-pepper-scoville-units-shu/',
#   'max_shu': 2000,
#   'name': 'Pasilla Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/poblano-pepper-scoville-units-shu/',
#   'max_shu': 2000,
#   'name': 'Poblano Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Tobago Seasoning Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1500,
#   'name': 'Georgia Flame Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1500,
#   'name': 'Prairie Fire Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1500,
#   'name': 'Achar',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1500,
#   'name': 'Almapaprika',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1500,
#   'name': 'Dedo de Moca',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1500,
#   'name': 'TAM Mild Jalapeno',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1400,
#   'name': 'Romanian Hot Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1400,
#   'name': 'Aji Mirasol Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1200,
#   'name': 'Peppadew Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Aji Panca Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Joe E Parker Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Agua Blanca',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Ají Dulce Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Ametista',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Beaver Dam Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Bedgi',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Biquinho',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Brinco de Princesa',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Calistan',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/coronado-pepper-scoville-units/',
#   'max_shu': 1000,
#   'name': 'Coronado Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Cubanelle Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Escabeche',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Gana Redonda',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 900,
#   'name': 'Banana Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/pepperoncini-pepper-scoville-units/',
#   'max_shu': 900,
#   'name': 'Pepperoncini',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 700,
#   'name': 'El-Paso',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 700,
#   'name': 'Holy Mole',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/santa-fe-grande-pepper-scoville-units/',
#   'max_shu': 700,
#   'name': 'Santa Fe Grande Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 600,
#   'name': 'Mariachi Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 600,
#   'name': 'Sonora Annaheim Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Avalon Button',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Babura Zelena',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Baldi',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Cachucha',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Cambuci',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Catarina',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Cherry Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Corbaci',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Cow Horn Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Cowhorn Chili',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Criollo',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Delicious Trinidad',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Frutka',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Georgescu Chocolate',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Guajilla de Zihutenejo',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Hot Cherry',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Italian Pepperoncini',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Karlo',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Keystone Giant',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Mexi Bell Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/pimento-pepper-scoville-heat-units/',
#   'max_shu': 500,
#   'name': 'Pimiento Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 250,
#   'name': 'Pasilla Bajio Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 150,
#   'name': 'Hot Navajo',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100,
#   'name': 'False Alarm Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Aconcagua',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Aji Chuncho',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Aladdin',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/sweet-bell-pepper-scoville-units/',
#   'max_shu': 0,
#   'name': 'Bell Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Branco Diamante',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'California Wonder Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Carliston',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Carmagnola Rosso',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Chinese Giant Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Corno Verde',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Corona',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Cuneo Giallo',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Diamond White',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Dove',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Early Sunsation',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Etham',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Figaro',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Filfil Darah',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Fushimi',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Giant Aconcagua Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Gigante',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Golden Treasure Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Greygo',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Gypsy Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Hershey',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Islander',
#   'source_name': 'Pepperheads'},
#  {'link': 'http://pepperheadsforlife.com/the-scoville-scale/jimmy-nardello-pepper/',
#   'max_shu': 0,
#   'name': 'Jimmy Nardello',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Jingle Bells',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Jupiter',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Kaala',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Kandil',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Marconi Purple',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Miniature Chocolate Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Miniature Yellow Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Orage Sun',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Purple Beauty',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Quadrato D’Asti',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Red Marconi Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Shishito Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Siling Lara Pepper',
#   'source_name': 'Pepperheads'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Tangerine',
#   'source_name': 'Pepperheads'}]

# %% [markdown]
# # Cayenne Diane

# %%
cd_url = "https://www.cayennediane.com/the-scoville-scale/"
cd_html = get_page_html(cd_url)
cd_table = cd_html.find("tbody")
cd_rows = cd_table.find_all("tr")
len(cd_rows)
# Out:
# 435

# %%
cd_rows[0]
# Out:
# <tr class="row-1 odd">
# <th class="column-1">Name</th><th class="column-2">Scovilles</th>
# </tr>

# %%
def process_cd_row(row):
    row_url = cd_url if not row.find("a") else row.find("a")["href"]
    row_data = [col.text for col in row.find_all("td")] + [row_url] + ["Cayenne Diane"]
    row_data[1] = int(row_data[1].replace(",", ""))
    return dict(zip(["name", "max_shu", "link", "source_name"], row_data))
    
cd_data = [process_cd_row(row) for row in cd_rows]
cd_data
# Out:
# [{'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 16000000,
#   'name': 'Pure Capsaicin',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/carolina-reaper/',
#   'max_shu': 2200000,
#   'name': 'Carolina Reaper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/trinidad-moruga-scorpion/',
#   'max_shu': 2000000,
#   'name': 'Trinidad Moruga Scorpion',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/7-pot-douglah/',
#   'max_shu': 1853396,
#   'name': '7 Pot Douglah',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/7-pot-primo/',
#   'max_shu': 1473480,
#   'name': '7 Pot Primo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/trinidad-scorpion-butch-t-pepper/',
#   'max_shu': 1463700,
#   'name': 'Trinidad Scorpion Butch T',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/komodo-dragon-chilli/',
#   'max_shu': 1400000,
#   'name': 'Komodo Dragon',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/naga-viper/',
#   'max_shu': 1382118,
#   'name': 'Naga Viper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/7-pot-brain-strain/',
#   'max_shu': 1350000,
#   'name': '7 Pot Brain Strain',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/7-pot-barrackpore/',
#   'max_shu': 1300000,
#   'name': '7 Pot Barrackpore',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/7-pot-jonah/',
#   'max_shu': 1200000,
#   'name': '7 Pot Jonah',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/7-pot-infinity/',
#   'max_shu': 1176182,
#   'name': '7 Pot Infinity',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/bedfordshire-super-naga/',
#   'max_shu': 1120000,
#   'name': 'Bedfordshire Super Naga',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/naga-morich/',
#   'max_shu': 1100000,
#   'name': 'Naga Morich',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/dorset-naga/',
#   'max_shu': 1100000,
#   'name': 'Dorset Naga',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/gibralta-spanish-naga-pepper/',
#   'max_shu': 1086844,
#   'name': 'Spanish Naga Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/bhut-jolokia-ghost-pepper/',
#   'max_shu': 1041427,
#   'name': 'Bhut Jolokia Pepper/Ghost Pepper/Naga Jolokia',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/bhut-jolokia-chocolate/',
#   'max_shu': 1001304,
#   'name': 'Chocolate Bhut Jolokia',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/trinidad-7-pot/',
#   'max_shu': 1000000,
#   'name': 'Trinidad 7 Pot/Pod',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000000,
#   'name': '7 Pot Bubblegum',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000000,
#   'name': '7 Pot Madballz',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000000,
#   'name': '7 Pot Chaguanas',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000000,
#   'name': '7 Pot Rennie',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000000,
#   'name': '7 Pot SR Strain',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000000,
#   'name': 'Bhut Jolokia Indian Carbon',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/trinidad-scorpion-cardi/',
#   'max_shu': 1000000,
#   'name': 'Trinidad Scorpion CARDI',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 900000,
#   'name': 'Raja Mirch',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 800000,
#   'name': 'Habanaga Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 800000,
#   'name': 'Nagabon Jolokia',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/red-savina-habanero/',
#   'max_shu': 580000,
#   'name': 'Red Savina Habanero',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500000,
#   'name': 'Aji Chombo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/devils-tongue-red/',
#   'max_shu': 500000,
#   'name': 'Devil’s Tongue Red',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500000,
#   'name': 'Pingo de Ouro',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/yucatan-white-habanero/',
#   'max_shu': 500000,
#   'name': 'Yucatan White Habanero',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 470000,
#   'name': 'Aribibi Gusano',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/caribbean-red-habanero/',
#   'max_shu': 400000,
#   'name': 'Caribbean Red Habanero',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 350000,
#   'name': 'Adjuma',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/chocolate-habanero/',
#   'max_shu': 350000,
#   'name': 'Chocolate Habanero',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/wiri-wiri/',
#   'max_shu': 350000,
#   'name': 'Guyana Wiri Wiri',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/habanero-orange/',
#   'max_shu': 350000,
#   'name': 'Habanero',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/hot-paper-lantern/',
#   'max_shu': 350000,
#   'name': 'Hot Paper Lantern',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 350000,
#   'name': 'Jamaican Hot',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/madame-jeanette-pepper/',
#   'max_shu': 350000,
#   'name': 'Madame Jeanette',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/habanero-peach/',
#   'max_shu': 350000,
#   'name': 'Peach Habanero',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/peruvian-white-habanero/',
#   'max_shu': 350000,
#   'name': 'Peruvian White Habanero',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/scotch-bonnet/',
#   'max_shu': 350000,
#   'name': 'Scotch Bonnet',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/tigerpaw-nr-habanero/',
#   'max_shu': 350000,
#   'name': 'TigerPaw-NR Habanero',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 350000,
#   'name': 'Zimbabwe Bird Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 325000,
#   'name': 'Big Sun Habanero',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/devils-tongue-yellow/',
#   'max_shu': 325000,
#   'name': 'Devil’s Tongue Yellow',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/fatalii/',
#   'max_shu': 325000,
#   'name': 'Fatalii',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/habanero-golden-yellow/',
#   'max_shu': 325000,
#   'name': 'Golden Habanero (Yellow)',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/habanero-mustard/',
#   'max_shu': 325000,
#   'name': 'Mustard Habanero',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/datil/',
#   'max_shu': 300000,
#   'name': 'Datil Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 300000,
#   'name': 'Piri Piri',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 300000,
#   'name': 'Red Cheese',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 300000,
#   'name': 'Thai Burapa',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 265000,
#   'name': 'Texas Chiltepin',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 250000,
#   'name': 'Pimenta de Neyde',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/rocoto-pepper/',
#   'max_shu': 250000,
#   'name': 'Rocoto Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 240000,
#   'name': 'Maori',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 225000,
#   'name': 'Bird’s Eye Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 186000,
#   'name': 'Ecuador Hot',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 160000,
#   'name': 'Shogaol',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 160000,
#   'name': 'Sparkler',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 150000,
#   'name': 'Cajamarca',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 150000,
#   'name': 'Jamaican Gold',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 150000,
#   'name': 'Kumataka',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/tepin-pepper/',
#   'max_shu': 150000,
#   'name': 'Tepin Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/carolina-cayenne/',
#   'max_shu': 125000,
#   'name': 'Carolina Cayenne',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/tabiche-pepper/',
#   'max_shu': 115000,
#   'name': 'Tabiche Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/bahamian-bird-pepper/',
#   'max_shu': 110000,
#   'name': 'Bahamian Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 108000,
#   'name': 'Aji Cito',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'African Birds Eye',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Ají Rojo Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Black Scorpion Tongue',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Byadgi Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/charleston-hot-pepper/',
#   'max_shu': 100000,
#   'name': 'Charleston Hot Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/tepin-pepper/',
#   'max_shu': 100000,
#   'name': 'Chiltepin Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'China Express Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Cili Goronong',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/diablo-grande-pepper/',
#   'max_shu': 100000,
#   'name': 'Diablo Grande',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Firecracker Pequin',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Indian Jwala',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/malagueta-pepper/',
#   'max_shu': 100000,
#   'name': 'Malagueta',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Mayan Cobanero Love Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Orange Thai',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Pepin',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Peri-Peri',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Piperine',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/purira-chili-pepper/',
#   'max_shu': 100000,
#   'name': 'Purira Chile Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Red Thai',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Siling Labuyo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/thai-dragon-pepper/',
#   'max_shu': 100000,
#   'name': 'Thai Dragon',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/thai-ornamental/',
#   'max_shu': 100000,
#   'name': 'Thai Ornamental',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/thai-pepper/',
#   'max_shu': 100000,
#   'name': 'Thai Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/thai-sun-pepper/',
#   'max_shu': 100000,
#   'name': 'Thai Sun Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/thai-super-chile/',
#   'max_shu': 100000,
#   'name': 'Thai Super Chile',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100000,
#   'name': 'Yellow Thai',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 81400,
#   'name': 'Suryaki Cluster',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 80000,
#   'name': 'Haimen',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/tien-tsin-pepper/',
#   'max_shu': 75000,
#   'name': 'Tianjin Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/yatsufusa-chile-pepper/',
#   'max_shu': 75000,
#   'name': 'Yatsufusa',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/prairie-fire/',
#   'max_shu': 70000,
#   'name': 'Prairie Fire',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 70000,
#   'name': 'Chi Chien',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 70000,
#   'name': 'Prik Kee Noo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 60000,
#   'name': 'Gingerol',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/pequin-pepper/',
#   'max_shu': 60000,
#   'name': 'Pequin Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 57000,
#   'name': 'African Pequin',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 55000,
#   'name': 'Chile Grande Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/aji-amarillo-pepper/',
#   'max_shu': 50000,
#   'name': 'Aji Amarillo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/aji-charapita/',
#   'max_shu': 50000,
#   'name': 'Aji Charapita',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Ají Crystal Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/aji-limo-chili-pepper/',
#   'max_shu': 50000,
#   'name': 'Ají Limo (Lemon Drop)',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/aji-omnicolor-pepper/',
#   'max_shu': 50000,
#   'name': 'Ají Omnicolor Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Akabare',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Aurora',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Balloon Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Black Cuban Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Bonney',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/cayenne-chile-pepper/',
#   'max_shu': 50000,
#   'name': 'Cayenne Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/cheyenne-pepper/',
#   'max_shu': 50000,
#   'name': 'Cheyenne Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Chinese Five Color',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Coban',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/cumari-do-para/',
#   'max_shu': 50000,
#   'name': 'Cumari Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Demre',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Desi Teekhi',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Diente de Perro',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'DKurnool',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Dong Xuan Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Dunso',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Etna',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Explosive Ember',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Faria',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Fiji',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Filius Blue',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Fluorescent Purple',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Goat Horn Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/golden-cayenne-pepper/',
#   'max_shu': 50000,
#   'name': 'Golden Cayenne Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Guarani',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/guntur-sannam-chili-pepper/',
#   'max_shu': 50000,
#   'name': 'Guntur Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Hermosillo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Hot Portugal Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Inca Berry Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Kurnool Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Large Purple Cayenne',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Large Red Thick Cayenne',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Little Nubian Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Maras Biber',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Marbles Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'McMahon’s Texas Bird Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Medusa’s Head Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/numex-twilight/',
#   'max_shu': 50000,
#   'name': 'NuMex Twilight Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Orange Manzano Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Punjab',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Purple Prince',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Pusa Jwala',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Rain Forest Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/red-amazon-pepper/',
#   'max_shu': 50000,
#   'name': 'Red Amazon',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/manzano-pepper/',
#   'max_shu': 50000,
#   'name': 'Manzano Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Red Squash Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Rooster Spur Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/santaka-chili-pepper/',
#   'max_shu': 50000,
#   'name': 'Santaka Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Satans Kiss Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Siling Haba Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/super-chili-pepper/',
#   'max_shu': 50000,
#   'name': 'Super Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/tabasco-pepper/',
#   'max_shu': 50000,
#   'name': 'Tabasco Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Tricolor variegata Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Urfa Biber',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 50000,
#   'name': 'Wild Baccatum',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/manzano-pepper/',
#   'max_shu': 50000,
#   'name': 'Yellow Manzano Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 45000,
#   'name': 'Chenzo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 45000,
#   'name': 'Long Slim Cayenne Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 42600,
#   'name': 'Beni Highland',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/dundicut-chili-pepper/',
#   'max_shu': 40000,
#   'name': 'Dundicut',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/guntur-sannam-chili-pepper/',
#   'max_shu': 40000,
#   'name': 'Guntur Sannam Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/hot-golden-nugget/',
#   'max_shu': 35000,
#   'name': 'Hot Golden Nugget',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Abchazskij Ostruyi',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/aci-sivri-pepper/',
#   'max_shu': 30000,
#   'name': 'Aci Sivri Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Afega Longa',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Aji Carmine',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Aji Criolla Sella',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Ata Barukono',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Australian Latern',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/barkers-hot-chili-pepper/',
#   'max_shu': 30000,
#   'name': 'Barker’s Hot',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Berbere',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Beslers Cherry',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/bishops-crown-pepper/',
#   'max_shu': 30000,
#   'name': 'Bishops Crown',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Black Pearl',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Black Prince',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Bode Amarela',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/bolivian-rainbow-chili-pepper/',
#   'max_shu': 30000,
#   'name': 'Bolivian Rainbow Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Bombilla Amarilla',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Bonanza Brasileira',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/brazilian-starfish/',
#   'max_shu': 30000,
#   'name': 'Brazilian Starfish',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Bubba',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/bulgarian-carrot/',
#   'max_shu': 30000,
#   'name': 'Bulgarian Carrot',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Cabai Burong',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Cabai Merah Besar',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Caballero',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chao Tian Jiao',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/chile-de-arbol/',
#   'max_shu': 30000,
#   'name': 'Chile de Arbol',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chile Inayague',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chile Maya',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chile Pepe',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chilito de Simojovel',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chinchi Uchu',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chivato',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Chupetinho',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/chile-de-arbol/',
#   'max_shu': 30000,
#   'name': 'De árbol Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Dedo de Bahamas',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Dieng Plateau',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Erva de Bode',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/fish-pepper/',
#   'max_shu': 30000,
#   'name': 'Fish Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Golden Heat',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Hahony Kacho',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Havaiana',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/hinkelhatz-hot-pepper/',
#   'max_shu': 30000,
#   'name': 'Hinkelhatz Hot Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/ho-chi-minh-hot-pepper/',
#   'max_shu': 30000,
#   'name': 'Ho Chi Minh Hot Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Holiday Cheer',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Inca Glow',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Inca Laranja',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Inca Red Drop',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Japones Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/jwala-finger-hot-pepper/',
#   'max_shu': 30000,
#   'name': 'Jwala Finger',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Kim Chi',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/aji-limo-chili-pepper/',
#   'max_shu': 30000,
#   'name': 'Lemon Drop',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Little Elf',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/manzano-pepper/',
#   'max_shu': 30000,
#   'name': 'Manzano',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Merah',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'New Delhi Long',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Onza Yellow',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Orozco',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/peter-pepper/',
#   'max_shu': 30000,
#   'name': 'Peter Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Pico de Pajaro',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Pimenta de Bode',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/quintisho-hot-pepper/',
#   'max_shu': 30000,
#   'name': 'Quintisho',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Royal Black',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Shipkas',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 30000,
#   'name': 'Takanotsume',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 27000,
#   'name': 'Stumpy',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 26500,
#   'name': 'Gambia',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/serrano-pepper/',
#   'max_shu': 25000,
#   'name': 'Serrano Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 25000,
#   'name': 'Tianying',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 23600,
#   'name': 'Tears Of Fire',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 23000,
#   'name': 'Chili Wili Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 23000,
#   'name': 'Halabi Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 23000,
#   'name': 'Serrano Huasteco Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 20000,
#   'name': 'Aji Colorado Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 20000,
#   'name': 'Ají Brazilian Pumpkin Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 20000,
#   'name': 'Ají Pineapple Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 20000,
#   'name': 'Onza Roja Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 20000,
#   'name': 'Peruvian Purple Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/ring-o-fire-cayenne/',
#   'max_shu': 20000,
#   'name': 'Ring-O-Fire Cayenne',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 17000,
#   'name': 'Aji Escabeche',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/hidalgo-chili-pepper/',
#   'max_shu': 17000,
#   'name': 'Hidalgo Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 16000,
#   'name': 'Capsiate',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15500,
#   'name': 'Aji Bento',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Abbraccio',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Afegã Curta',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Aji Cobincho',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Balãozinho',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Cseresznye Paprika',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Dutch Red',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Estrela-do-Mar',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Hot Banana Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Israeli Hot',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Jarales',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 15000,
#   'name': 'Yellow Wax Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 12000,
#   'name': 'Costeno Rojo Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/aleppo-pepper/',
#   'max_shu': 10000,
#   'name': 'Aleppo Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/alma-spicy-paprika/',
#   'max_shu': 10000,
#   'name': 'Alma Spicy Paprika',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Biker Billy Jalapeno',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/chipotle-morita/',
#   'max_shu': 10000,
#   'name': 'Chipotle Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Dutch Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Earbob',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/fresno-chili-pepper/',
#   'max_shu': 10000,
#   'name': 'Fresno Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Hot Apple Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/hungarian-wax-pepper/',
#   'max_shu': 10000,
#   'name': 'Hungarian Wax Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/jalapeno-pepper/',
#   'max_shu': 10000,
#   'name': 'Jalapeño Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/jaloro-pepper-yellow-jalapeno/',
#   'max_shu': 10000,
#   'name': 'Jaloro Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/kung-pao-pepper/',
#   'max_shu': 10000,
#   'name': 'Kung Pao Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Louisiana Hot Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Lumbre Hot',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 10000,
#   'name': 'Pasilla de Oaxaco Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/purple-jalapeno-pepper/',
#   'max_shu': 10000,
#   'name': 'Purple Jalapeño',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/puya-chile-pepper/',
#   'max_shu': 10000,
#   'name': 'Puya Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 9000,
#   'name': 'Purple Tiger ‘Trifetti’',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 8500,
#   'name': 'Long Thick Cayenne',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/cascabel-chili-pepper/',
#   'max_shu': 8000,
#   'name': 'Cascabel Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 8000,
#   'name': 'Chile Gordo Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/guajillo-chili-pepper/',
#   'max_shu': 8000,
#   'name': 'Guajillo Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 8000,
#   'name': 'Huachinango Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 8000,
#   'name': 'Mitla Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 8000,
#   'name': 'New Mexican Anaheim Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 8000,
#   'name': 'Pretty Purple',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/sandia-hot-pepper/',
#   'max_shu': 7000,
#   'name': 'Sandia Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/chimayo-chili/',
#   'max_shu': 6000,
#   'name': 'Chimayo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Atomic Heart',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Azr',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Baccio di Satana',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Bermuda',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Bouquet',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Caloro Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/candlelight-pepper/',
#   'max_shu': 5000,
#   'name': 'Candlelight Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Cenoura Búlgara',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Cereja',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/cherry-bomb-pepper/',
#   'max_shu': 5000,
#   'name': 'Cherry Bomb Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Chilcostle Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Chile de Cuscutlan',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Chintexle',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Cochabamba',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Cochiti',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Cyklon',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Dhanraj',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Equador Roxa',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Floral Gem',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Fogo Explosivo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Goan',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Gulbarga',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Hari Mirch',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/hatch-chili-pepper/',
#   'max_shu': 5000,
#   'name': 'Hatch Chile Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Huasteco Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Huatulco Puntado',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Inca',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Inchanga',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Inferno Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Isleta',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Jemes',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Kalia',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Kerinting',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Kori Sitakame',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/mirasol-chili-pepper/',
#   'max_shu': 5000,
#   'name': 'Mirasol Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'New Mexico Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Nosegay',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'NuMex 6-4 Heritage',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Serrano Tampequino Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Ubatuba Cambuci',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 5000,
#   'name': 'Volcano Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 4500,
#   'name': 'Mesilla Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 4000,
#   'name': 'Ancho San Luis Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 4000,
#   'name': 'Big Jim Heritage',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/cascabella/',
#   'max_shu': 4000,
#   'name': 'Cascabella',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 4000,
#   'name': 'Espelette',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 4000,
#   'name': 'San Ardo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 3000,
#   'name': 'Pulla Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2500,
#   'name': 'Aji Andina',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2500,
#   'name': 'Ají Habanero Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2500,
#   'name': 'Alcalde',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2500,
#   'name': 'Ammazzo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/anaheim-chile-pepper/',
#   'max_shu': 2500,
#   'name': 'Anaheim Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/hungarian-black-pepper/',
#   'max_shu': 2500,
#   'name': 'Black Hungarian Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2500,
#   'name': 'Calabria',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/anaheim-chile-pepper/',
#   'max_shu': 2500,
#   'name': 'Californian Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2500,
#   'name': 'Japanese Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/anaheim-chile-pepper/',
#   'max_shu': 2500,
#   'name': 'Magdalena Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/numex-big-jim/',
#   'max_shu': 2500,
#   'name': 'NuMex Big Jim',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/padron-pepper/',
#   'max_shu': 2500,
#   'name': 'Padron Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2500,
#   'name': 'Poinsettia Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2500,
#   'name': 'Prometheus Springs Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/rocotillo-chili-pepper/',
#   'max_shu': 2500,
#   'name': 'Rocotillo Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/ancho-chili-pepper/',
#   'max_shu': 2500,
#   'name': 'Ancho Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/chilaca-pepper/',
#   'max_shu': 2000,
#   'name': 'Chilaca Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Chilhuacle Negro Chile',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Costeno Amarillo Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Espanola Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Hawaiian Sweet Hot Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/mulato-chili-pepper/',
#   'max_shu': 2000,
#   'name': 'Mulato Isleno Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/pasilla-pepper/',
#   'max_shu': 2000,
#   'name': 'Pasilla Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/poblano-chili-pepper/',
#   'max_shu': 2000,
#   'name': 'Poblano Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Szentesi Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 2000,
#   'name': 'Tobago Seasoning Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1500,
#   'name': 'Achar',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/alma-paprika-pepper-sweet-apple/',
#   'max_shu': 1500,
#   'name': 'Alma Paprika',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1500,
#   'name': 'Dedo de Moca',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1500,
#   'name': 'Georgia Flame Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1500,
#   'name': 'TAM Mild Jalapeno',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1400,
#   'name': 'Aji Mirasol Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1400,
#   'name': 'Romanian Hot Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/piquante-pepper-peppadew/',
#   'max_shu': 1200,
#   'name': 'Peppadew Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Agua Blanca',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/aji-panca-pepper/',
#   'max_shu': 1000,
#   'name': 'Aji Panca Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Ají Dulce Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Ametista',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/beaver-dam-pepper/',
#   'max_shu': 1000,
#   'name': 'Beaver Dam Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Bedgi',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/pimenta-biquinho-little-beak-peppers/',
#   'max_shu': 1000,
#   'name': 'Biquinho',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Brinco de Princesa',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Calistan',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Coronado Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/cubanelle-chile-pepper/',
#   'max_shu': 1000,
#   'name': 'Cubanelle Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Escabeche',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 1000,
#   'name': 'Gana Redonda',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/italian-long-hots/',
#   'max_shu': 1000,
#   'name': 'Italian Long Hots',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/numex-joe-e-parker-chili-pepper/',
#   'max_shu': 1000,
#   'name': 'NuMex Joe E. Parker Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 700,
#   'name': 'El-Paso',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 700,
#   'name': 'Holy Mole',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/santa-fe-grande-pepper/',
#   'max_shu': 700,
#   'name': 'Santa Fe Grande Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 600,
#   'name': 'Mariachi Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/sonora-chile-pepper/',
#   'max_shu': 600,
#   'name': 'Sonora Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Avalon Button',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Babura Zelena',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Baldi',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/banana-pepper/',
#   'max_shu': 500,
#   'name': 'Banana Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Cachucha',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Cambuci',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Catarina',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Corbaci',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Cow Horn Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Cowhorn Chili',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Criollo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Delicious Trinidad',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Frutka',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Georgescu Chocolate',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Guajilla de Zihutenejo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/pimento-hot-cherry-pepper/',
#   'max_shu': 500,
#   'name': 'Hot Cherry Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Karlo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Keystone Giant',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 500,
#   'name': 'Mexi Bell Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/pepperoncini-italian/',
#   'max_shu': 500,
#   'name': 'Pepperoncini',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/pimento-hot-cherry-pepper/',
#   'max_shu': 500,
#   'name': 'Pimiento Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/shishito-pepper/',
#   'max_shu': 500,
#   'name': 'Shishito Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/trinidad-perfume-pepper/',
#   'max_shu': 500,
#   'name': 'Trinidad Perfume Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/corno-di-toro-pepper/',
#   'max_shu': 250,
#   'name': 'Corno di Toro Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 250,
#   'name': 'Pasilla Bajio Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 150,
#   'name': 'Hot Navajo',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 100,
#   'name': 'False Alarm Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/italian-sweet-pepper/',
#   'max_shu': 0,
#   'name': 'Italian Sweet Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Aconcagua',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Aji Chuncho',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/the-scoville-scale/',
#   'max_shu': 0,
#   'name': 'Aladdin',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/sweet-bell-peppers/',
#   'max_shu': 0,
#   'name': 'Bell Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/italian-sweet-pepper/',
#   'max_shu': 0,
#   'name': 'Italian Sweet Pepper',
#   'source_name': 'Cayenne Diane'},
#  {'link': 'https://www.cayennediane.com/peppers/melrose-pepper/',
#   'max_shu': 0,
#   'name': 'Melrose Pepper',
#   'source_name': 'Cayenne Diane'}]

# %% [markdown]
# # HotStuff

# %%
hotstuff_url = "http://ushotstuff.com/Heat.Scale.htm"

# %%
hotstuff = get_page_html(hotstuff_url)
len(hotstuff.find("table", id="G2").find_all("tr")) # not all of the entries

# %%
path_to_chromedriver = '/Users/asiega/Development/chromedriver' # change path as needed
browser = webdriver.Chrome(executable_path = path_to_chromedriver)
browser.get(hotstuff_url)
table_xpath = '//*[@id="G2"]/tbody'
table_element = browser.find_element_by_xpath(table_xpath)

# %%
hotstuff_html = BeautifulSoup(table_element.get_attribute('innerHTML'), "html.parser")
hotstuff_peppers = hotstuff_html.find_all("tr")
len(hotstuff_peppers) # much better!
# Out:
# 372

# %%
def sanitize_shu(shu):
    shu = shu.text.strip().split(" ~ ")
    if len(shu) == 1:
        if "-" in shu[0]:
            min_shu, max_shu = shu[0].split("-")
            magnitude = "".join(max_shu.split(",")[1:])
            return [int(min_shu+magnitude), int(max_shu.replace(",", ""))]
        return [None, int(shu[0].replace(",", ""))]
    return [int(s.replace(",", "")) for s in shu]
    

def sanitize_name(name):
    return name.text.strip()

def get_link(link):
    if len(link.findChildren()) == 0:
        return hotstuff_url # link, location, species
    return "http://ushotstuff.com/" + link.find("a", href=True)["href"] # only want first link

def extract_hotstuff_pepper_info(row):
    elements = row.find_all("td")
    try:
        link, name, shu = [e for e in elements]
        name = sanitize_name(name)
        link = get_link(link)
        shu = sanitize_shu(shu)
        return dict(zip(["name", "link", "min_shu", "max_shu"], [name, link] + shu))
    except:
        if len(row) > 1:
            name, shu = row.find_all('td')
            name = sanitize_name(name)
            shu = sanitize_shu(shu)
            link = "http://ushotstuff.com/Heat.Scale.htm"
            return dict(zip(["name", "link", "min_shu", "max_shu"], [name, link] + shu))

def generate_hotstuff_data(pepper_html):
    clean_hotstuff = [extract_hotstuff_pepper_info(row) for row in pepper_html[1:] if extract_hotstuff_pepper_info(row)] # skip colheader
    hotstuff_data = pd.DataFrame(clean_hotstuff)
    hotstuff_data["source_name"] = "Uncle Steve's Hot Stuff"
    return hotstuff_data

        
hotstuff_data = generate_hotstuff_data(hotstuff_peppers)
hotstuff_data
# Out:
#                                                   link   max_shu     min_shu  \
# 0                 http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 1                 http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 2                 http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 3                 http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 4                 http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 5                 http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 6                 http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 7                 http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 8                 http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 9                 http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 10                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 11                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 12                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 13                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 14                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 15                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 16                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 17                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 18                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 19                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 20                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 21                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 22                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 23                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 24                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 25                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 26                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 27                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 28                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# 29                http://ushotstuff.com/Heat.Scale.htm         0         NaN
# ..                                                 ...       ...         ...
# 340  http://ushotstuff.com/pepper-seeds/FataliiSeed...    325000    125000.0
# 341               http://ushotstuff.com/Heat.Scale.htm    325000    130000.0
# 342               http://ushotstuff.com/Heat.Scale.htm    325000    150000.0
# 343               http://ushotstuff.com/Heat.Scale.htm    325000     90000.0
# 344               http://ushotstuff.com/Heat.Scale.htm    348000    265000.0
# 345               http://ushotstuff.com/Heat.Scale.htm    350000    150000.0
# 346               http://ushotstuff.com/Heat.Scale.htm    400000    120000.0
# 347  http://ushotstuff.com/pepper-seeds/ChocolateHa...    425000    325000.0
# 348               http://ushotstuff.com/Heat.Scale.htm    470000    300000.0
# 349               http://ushotstuff.com/Heat.Scale.htm    500000    100000.0
# 350               http://ushotstuff.com/Heat.Scale.htm    500000    100000.0
# 351  http://ushotstuff.com/Cpages/RedSavinaHabanero...    575000    350000.0
# 352               http://ushotstuff.com/Heat.Scale.htm    800000    500000.0
# 353               http://ushotstuff.com/Heat.Scale.htm    800000    750000.0
# 354               http://ushotstuff.com/Heat.Scale.htm    900000    800000.0
# 355               http://ushotstuff.com/Heat.Scale.htm    970000    800000.0
# 356               http://ushotstuff.com/Heat.Scale.htm   1034910    770000.0
# 357               http://ushotstuff.com/Heat.Scale.htm   1067286    800000.0
# 358               http://ushotstuff.com/Heat.Scale.htm   1086844    900000.0
# 359               http://ushotstuff.com/Heat.Scale.htm   1382118    800000.0
# 360  http://ushotstuff.com/pepper-seeds/TrinidadSco...   1390000   1029000.0
# 361  http://ushotstuff.com/pepper-seeds/NagaJolokia...   1578000   1020000.0
# 362               http://ushotstuff.com/Heat.Scale.htm   1850000   1169000.0
# 363  http://ushotstuff.com/pepper-seeds/MorugaScorp...   2009231   1200000.0
# 364               http://ushotstuff.com/Heat.Scale.htm   2100000   1200000.0
# 365               http://ushotstuff.com/Heat.Scale.htm   3000000   2000000.0
# 366               http://ushotstuff.com/Heat.Scale.htm   5300000         NaN
# 367               http://ushotstuff.com/Heat.Scale.htm   8600000         NaN
# 368               http://ushotstuff.com/Heat.Scale.htm   9100000         NaN
# 369               http://ushotstuff.com/Heat.Scale.htm  16000000  15000000.0
#
#                             name              source_name
# 0                All Sweet Bells  Uncle Steve's Hot Stuff
# 1                      Aconcagua  Uncle Steve's Hot Stuff
# 2                    Aji Chuncho  Uncle Steve's Hot Stuff
# 3                        Aladdin  Uncle Steve's Hot Stuff
# 4                Branco Diamante  Uncle Steve's Hot Stuff
# 5                      Carliston  Uncle Steve's Hot Stuff
# 6               Carmagnola Rosso  Uncle Steve's Hot Stuff
# 7                    Corno Verde  Uncle Steve's Hot Stuff
# 8                         Corona  Uncle Steve's Hot Stuff
# 9                   Cuneo Giallo  Uncle Steve's Hot Stuff
# 10                 Diamond White  Uncle Steve's Hot Stuff
# 11                          Dove  Uncle Steve's Hot Stuff
# 12               Early Sunsation  Uncle Steve's Hot Stuff
# 13                         Etham  Uncle Steve's Hot Stuff
# 14                        Figaro  Uncle Steve's Hot Stuff
# 15                  Filfil Darah  Uncle Steve's Hot Stuff
# 16                       Fushimi  Uncle Steve's Hot Stuff
# 17                       Gigante  Uncle Steve's Hot Stuff
# 18                        Greygo  Uncle Steve's Hot Stuff
# 19                       Hershey  Uncle Steve's Hot Stuff
# 20                 Hungarian Wax  Uncle Steve's Hot Stuff
# 21                      Islander  Uncle Steve's Hot Stuff
# 22                Jimmy Nardello  Uncle Steve's Hot Stuff
# 23                  Jingle Bells  Uncle Steve's Hot Stuff
# 24                       Jupiter  Uncle Steve's Hot Stuff
# 25                         Kaala  Uncle Steve's Hot Stuff
# 26                        Kandil  Uncle Steve's Hot Stuff
# 27                Marconi Purple  Uncle Steve's Hot Stuff
# 28            NuMex Conquistador  Uncle Steve's Hot Stuff
# 29                     Orage Sun  Uncle Steve's Hot Stuff
# ..                           ...                      ...
# 340                      Fatalii  Uncle Steve's Hot Stuff
# 341               White Habanero  Uncle Steve's Hot Stuff
# 342              Orange Habanero  Uncle Steve's Hot Stuff
# 343                Scotch Bonnet  Uncle Steve's Hot Stuff
# 344                  TigrePaw-NR  Uncle Steve's Hot Stuff
# 345                       Adjuma  Uncle Steve's Hot Stuff
# 346                Caribbean Red  Uncle Steve's Hot Stuff
# 347            Choclate Habanero  Uncle Steve's Hot Stuff
# 348               Aribibi Gusano  Uncle Steve's Hot Stuff
# 349                   Aji Chombo  Uncle Steve's Hot Stuff
# 350                Pingo de Ouro  Uncle Steve's Hot Stuff
# 351          Red Savina Habanero  Uncle Steve's Hot Stuff
# 352                     Habanaga  Uncle Steve's Hot Stuff
# 353                      Nagabon  Uncle Steve's Hot Stuff
# 354                   Raja Mirch  Uncle Steve's Hot Stuff
# 355                  Dorset Naga  Uncle Steve's Hot Stuff
# 356                  Naga Morich  Uncle Steve's Hot Stuff
# 357                     Infinity  Uncle Steve's Hot Stuff
# 358                Naga Gibralta  Uncle Steve's Hot Stuff
# 359                   Naga Viper  Uncle Steve's Hot Stuff
# 360            Trinidad Scorpion  Uncle Steve's Hot Stuff
# 361  Naga Jolokia "Ghost Pepper"  Uncle Steve's Hot Stuff
# 362               Choclate 7 Pot  Uncle Steve's Hot Stuff
# 363              Moruga Scorpion  Uncle Steve's Hot Stuff
# 364              Carolina Reaper  Uncle Steve's Hot Stuff
# 365          Common Pepper Spray  Uncle Steve's Hot Stuff
# 366           Police Grade Spray  Uncle Steve's Hot Stuff
# 367         Homodihydrocapsaicin  Uncle Steve's Hot Stuff
# 368          Nordihydrocapsaicin  Uncle Steve's Hot Stuff
# 369               Pure Capsaicin  Uncle Steve's Hot Stuff
#
# [370 rows x 5 columns]

# %%
hotstuff_seed_html = get_page_html("http://ushotstuff.com/").find("table", class_="T1")

seed_data = []

for row in hotstuff_seed_html.find_all("tr")[1:]:
    row_tds = row.find_all("td")
    row_data = {
        "link": "http://ushotstuff.com/" + row.find("a")["href"],
        "heat": row_tds[1].text.lower(),
        "species": row_tds[2].text.lower()
    }
    seed_data.append(row_data)
    
seed_data = pd.DataFrame(seed_data)
seed_data
# Out:
#             heat                                               link  \
# 0            hot  http://ushotstuff.com/pepper-seeds/AjiHabanero...
# 1            hot  http://ushotstuff.com/pepper-seeds/AjiOmni-Col...
# 2      verry hot  http://ushotstuff.com/pepper-seeds/TrinidadSco...
# 3    mild-medium  http://ushotstuff.com/pepper-seeds/BishopsCrow...
# 4            hot  http://ushotstuff.com/pepper-seeds/BolivianRai...
# 5     low-medium  http://ushotstuff.com/pepper-seeds/BrazilianSt...
# 6            hot  http://ushotstuff.com/pepper-seeds/RedSquashSe...
# 7         medium  http://ushotstuff.com/pepper-seeds/ChineseMult...
# 8       very hot  http://ushotstuff.com/pepper-seeds/ChocolateHa...
# 9            hot  http://ushotstuff.com/pepper-seeds/CobinchoSee...
# 10    medium-hot  http://ushotstuff.com/pepper-seeds/DeArbolSeed...
# 11      very hot  http://ushotstuff.com/pepper-seeds/DevilTongue...
# 12      very hot  http://ushotstuff.com/pepper-seeds/FataliiSeed...
# 13       nuclear  http://ushotstuff.com/pepper-seeds/NagaJolokia...
# 14       nuclear  http://ushotstuff.com/pepper-seeds/NagaJolokia...
# 15        medium  http://ushotstuff.com/pepper-seeds/NosegaySeed...
# 16           hot  http://ushotstuff.com/pepper-seeds/PoinsettiaS...
# 17    low-medium  http://ushotstuff.com/pepper-seeds/RedCherrySe...
# 18      very hot  http://ushotstuff.com/pepper-seeds/RedSavinaSe...
# 19    low-medium  http://ushotstuff.com/pepper-seeds/PeterPepper...
# 20    low-medium  http://ushotstuff.com/pepper-seeds/BrazilianSt...
# 21  hot-very hot  http://ushotstuff.com/pepper-seeds/TepinChileS...
# 22  hot-very hot  http://ushotstuff.com/pepper-seeds/TexasChilte...
# 23        medium  http://ushotstuff.com/pepper-seeds/TwilightSee...
# 24    medium-hot  http://ushotstuff.com/pepper-seeds/BlackPrince...
# 25           n/a  http://ushotstuff.com/pepper-seeds/GarlicChive...
# 26            na   http://ushotstuff.com/pepper-seeds/OkraSeeds.htm
#
#                    species
# 0                baccatuum
# 1                baccatuum
# 2                 chinense
# 3                baccatuum
# 4                   annuum
# 5                baccatuum
# 6                   annuum
# 7                   annuum
# 8                 chinense
# 9                    exile
# 10                  annuum
# 11                chinense
# 12                chinense
# 13                chinense
# 14                chinense
# 15                  annuum
# 16                  annuum
# 17                  annuum
# 18                chinense
# 19                  annuum
# 20               baccatuum
# 21                  annuum
# 22                  annuum
# 23                  annuum
# 24                  annuum
# 25        allium tuberosum
# 26  abelmoschus esculentus

# %%
hotstuff_data.merge(seed_data, how="left")
# Out:
#                                                   link  max_shu    min_shu  \
# 0                 http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 1                 http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 2                 http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 3                 http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 4                 http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 5                 http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 6                 http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 7                 http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 8                 http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 9                 http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 10                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 11                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 12                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 13                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 14                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 15                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 16                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 17                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 18                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 19                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 20                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 21                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 22                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 23                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 24                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 25                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 26                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 27                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 28                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# 29                http://ushotstuff.com/Heat.Scale.htm        0        NaN
# ..                                                 ...      ...        ...
# 335  http://ushotstuff.com/pepper-seeds/TepinChileS...   265000   100000.0
# 336  http://ushotstuff.com/pepper-seeds/TexasChilte...   265000   100000.0
# 337               http://ushotstuff.com/Heat.Scale.htm   300000   100000.0
# 338               http://ushotstuff.com/Heat.Scale.htm   300000   180000.0
# 339  http://ushotstuff.com/pepper-seeds/DevilTongue...   325000   125000.0
# 340  http://ushotstuff.com/pepper-seeds/FataliiSeed...   325000   125000.0
# 341               http://ushotstuff.com/Heat.Scale.htm   325000   130000.0
# 342               http://ushotstuff.com/Heat.Scale.htm   325000   150000.0
# 343               http://ushotstuff.com/Heat.Scale.htm   325000    90000.0
# 344               http://ushotstuff.com/Heat.Scale.htm   348000   265000.0
# 345               http://ushotstuff.com/Heat.Scale.htm   350000   150000.0
# 346               http://ushotstuff.com/Heat.Scale.htm   400000   120000.0
# 347  http://ushotstuff.com/pepper-seeds/ChocolateHa...   425000   325000.0
# 348               http://ushotstuff.com/Heat.Scale.htm   470000   300000.0
# 349               http://ushotstuff.com/Heat.Scale.htm   500000   100000.0
# 350               http://ushotstuff.com/Heat.Scale.htm   500000   100000.0
# 351  http://ushotstuff.com/Cpages/RedSavinaHabanero...   575000   350000.0
# 352               http://ushotstuff.com/Heat.Scale.htm   800000   500000.0
# 353               http://ushotstuff.com/Heat.Scale.htm   800000   750000.0
# 354               http://ushotstuff.com/Heat.Scale.htm   900000   800000.0
# 355               http://ushotstuff.com/Heat.Scale.htm   970000   800000.0
# 356               http://ushotstuff.com/Heat.Scale.htm  1034910   770000.0
# 357               http://ushotstuff.com/Heat.Scale.htm  1067286   800000.0
# 358               http://ushotstuff.com/Heat.Scale.htm  1086844   900000.0
# 359               http://ushotstuff.com/Heat.Scale.htm  1382118   800000.0
# 360  http://ushotstuff.com/pepper-seeds/TrinidadSco...  1390000  1029000.0
# 361  http://ushotstuff.com/pepper-seeds/NagaJolokia...  1578000  1020000.0
# 362               http://ushotstuff.com/Heat.Scale.htm  1850000  1169000.0
# 363  http://ushotstuff.com/pepper-seeds/MorugaScorp...  2009231  1200000.0
# 364               http://ushotstuff.com/Heat.Scale.htm  2100000  1200000.0
#
#                             name              source_name          heat  \
# 0                All Sweet Bells  Uncle Steve's Hot Stuff           NaN
# 1                      Aconcagua  Uncle Steve's Hot Stuff           NaN
# 2                    Aji Chuncho  Uncle Steve's Hot Stuff           NaN
# 3                        Aladdin  Uncle Steve's Hot Stuff           NaN
# 4                Branco Diamante  Uncle Steve's Hot Stuff           NaN
# 5                      Carliston  Uncle Steve's Hot Stuff           NaN
# 6               Carmagnola Rosso  Uncle Steve's Hot Stuff           NaN
# 7                    Corno Verde  Uncle Steve's Hot Stuff           NaN
# 8                         Corona  Uncle Steve's Hot Stuff           NaN
# 9                   Cuneo Giallo  Uncle Steve's Hot Stuff           NaN
# 10                 Diamond White  Uncle Steve's Hot Stuff           NaN
# 11                          Dove  Uncle Steve's Hot Stuff           NaN
# 12               Early Sunsation  Uncle Steve's Hot Stuff           NaN
# 13                         Etham  Uncle Steve's Hot Stuff           NaN
# 14                        Figaro  Uncle Steve's Hot Stuff           NaN
# 15                  Filfil Darah  Uncle Steve's Hot Stuff           NaN
# 16                       Fushimi  Uncle Steve's Hot Stuff           NaN
# 17                       Gigante  Uncle Steve's Hot Stuff           NaN
# 18                        Greygo  Uncle Steve's Hot Stuff           NaN
# 19                       Hershey  Uncle Steve's Hot Stuff           NaN
# 20                 Hungarian Wax  Uncle Steve's Hot Stuff           NaN
# 21                      Islander  Uncle Steve's Hot Stuff           NaN
# 22                Jimmy Nardello  Uncle Steve's Hot Stuff           NaN
# 23                  Jingle Bells  Uncle Steve's Hot Stuff           NaN
# 24                       Jupiter  Uncle Steve's Hot Stuff           NaN
# 25                         Kaala  Uncle Steve's Hot Stuff           NaN
# 26                        Kandil  Uncle Steve's Hot Stuff           NaN
# 27                Marconi Purple  Uncle Steve's Hot Stuff           NaN
# 28            NuMex Conquistador  Uncle Steve's Hot Stuff           NaN
# 29                     Orage Sun  Uncle Steve's Hot Stuff           NaN
# ..                           ...                      ...           ...
# 335                 Tepin (Wild)  Uncle Steve's Hot Stuff  hot-very hot
# 336              Texas Chiltepin  Uncle Steve's Hot Stuff  hot-very hot
# 337                        Datil  Uncle Steve's Hot Stuff           NaN
# 338                Zimbabwe Bird  Uncle Steve's Hot Stuff           NaN
# 339                 Devil Tongue  Uncle Steve's Hot Stuff      very hot
# 340                      Fatalii  Uncle Steve's Hot Stuff      very hot
# 341               White Habanero  Uncle Steve's Hot Stuff           NaN
# 342              Orange Habanero  Uncle Steve's Hot Stuff           NaN
# 343                Scotch Bonnet  Uncle Steve's Hot Stuff           NaN
# 344                  TigrePaw-NR  Uncle Steve's Hot Stuff           NaN
# 345                       Adjuma  Uncle Steve's Hot Stuff           NaN
# 346                Caribbean Red  Uncle Steve's Hot Stuff           NaN
# 347            Choclate Habanero  Uncle Steve's Hot Stuff      very hot
# 348               Aribibi Gusano  Uncle Steve's Hot Stuff           NaN
# 349                   Aji Chombo  Uncle Steve's Hot Stuff           NaN
# 350                Pingo de Ouro  Uncle Steve's Hot Stuff           NaN
# 351          Red Savina Habanero  Uncle Steve's Hot Stuff           NaN
# 352                     Habanaga  Uncle Steve's Hot Stuff           NaN
# 353                      Nagabon  Uncle Steve's Hot Stuff           NaN
# 354                   Raja Mirch  Uncle Steve's Hot Stuff           NaN
# 355                  Dorset Naga  Uncle Steve's Hot Stuff           NaN
# 356                  Naga Morich  Uncle Steve's Hot Stuff           NaN
# 357                     Infinity  Uncle Steve's Hot Stuff           NaN
# 358                Naga Gibralta  Uncle Steve's Hot Stuff           NaN
# 359                   Naga Viper  Uncle Steve's Hot Stuff           NaN
# 360            Trinidad Scorpion  Uncle Steve's Hot Stuff     verry hot
# 361  Naga Jolokia "Ghost Pepper"  Uncle Steve's Hot Stuff       nuclear
# 362               Choclate 7 Pot  Uncle Steve's Hot Stuff           NaN
# 363              Moruga Scorpion  Uncle Steve's Hot Stuff           NaN
# 364              Carolina Reaper  Uncle Steve's Hot Stuff           NaN
#
#       species
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# ..        ...
# 335    annuum
# 336    annuum
# 337       NaN
# 338       NaN
# 339  chinense
# 340  chinense
# 341       NaN
# 342       NaN
# 343       NaN
# 344       NaN
# 345       NaN
# 346       NaN
# 347  chinense
# 348       NaN
# 349       NaN
# 350       NaN
# 351       NaN
# 352       NaN
# 353       NaN
# 354       NaN
# 355       NaN
# 356       NaN
# 357       NaN
# 358       NaN
# 359       NaN
# 360  chinense
# 361  chinense
# 362       NaN
# 363       NaN
# 364       NaN
#
# [365 rows x 7 columns]

# %%
BASE_URL = "http://ushotstuff.com/Heat.Scale.htm"
SEED_URL = "http://ushotstuff.com/"


### FETCHER FUNCTIONS

def run(headers, driver_path):
    # scrape and sanitize base pepper data
    base_html = _scrape_pepper_page(driver_path)
    base_data = [_extract_hotstuff_pepper_info(row) for row in base_html[1:] if _extract_hotstuff_pepper_info(row)] # skip colheader
    base_data = pd.DataFrame(base_data)
    base_data["source_name"] = "Uncle Steve's Hot Stuff"
    print("%d peppers fetched from HotStuff!" % len(base_data))

    # scrape seed data
    seed_html = get_page_html("http://ushotstuff.com/", headers).find("table", class_="T1")
    seed_data = [_get_seed_row(row) for row in hotstuff_seed_html.find_all("tr")[1:]] # skip header row
    seed_data = pd.DataFrame(seed_data)

    # join seed data to base data, where available
    return base_data.merge(seed_data, how="left")

def _get_page_html(url, headers):
    request = urllib.request.Request(url, headers=headers)
    return BeautifulSoup(urllib.request.urlopen(request).read().decode('utf-8'), 'html.parser')

def _scrape_pepper_page(driver_path):
    # set up browser with selenium
    browser = webdriver.Chrome(executable_path=driver_path)
    browser.get(BASE_URL)

    # find and parse table element with all of the pepper rows
    table_xpath = '//*[@id="G2"]/tbody'
    table_element = browser.find_element_by_xpath(table_xpath)
    hotstuff_html = BeautifulSoup(table_element.get_attribute('innerHTML'), "html.parser")
    return hotstuff_html.find_all("tr")


## SANITIZATION FUNCTIONS

def _get_seed_row(row):
    row_tds = row.find_all("td")
    row_data = {
        "link": "http://ushotstuff.com/" + row.find("a")["href"],
        "heat": row_tds[1].text.lower(),
        "species": row_tds[2].text.lower()
    }
    return row_data

def _sanitize_shu(shu):
    shu = shu.text.strip().split(" ~ ")
    if len(shu) == 1:
        if "-" in shu[0]:
            min_shu, max_shu = shu[0].split("-")
            magnitude = "".join(max_shu.split(",")[1:])
            return [int(min_shu+magnitude), int(max_shu.replace(",", ""))]
        return [None, int(shu[0].replace(",", ""))]
    return [int(s.replace(",", "")) for s in shu]

def _sanitize_name(name):
    return name.text.strip()

def _get_link(link):
    if len(link.findChildren()) == 0:
        return link # link, heat, species to match to seed data later
    return "http://ushotstuff.com/" + link.find("a", href=True)["href"] # only want first link

def _extract_hotstuff_pepper_info(row):
    elements = row.find_all("td")
    try:
        link, name, shu = [e for e in elements]
        name = _sanitize_name(name)
        link = _get_link(link)
        shu = _sanitize_shu(shu)
        return dict(zip(["name", "link", "min_shu", "max_shu"], [name, link] + shu))
    except: # malformed rows of not-quite-peppers at the end of the data; good for pepper comparison
        if len(row) > 1:
            name, shu = row.find_all('td')
            name = _sanitize_name(name)
            shu = _sanitize_shu(shu)
            link = "http://ushotstuff.com/Heat.Scale.htm"
            return dict(zip(["name", "link", "min_shu", "max_shu"], [name, link] + shu))

# %%
HEADERS = {
    "user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36(KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36"
}
DRIVER_PATH = '/Users/asiega/Development/chromedriver'

run(HEADERS, DRIVER_PATH)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-6cbcd7707654> in <module>()
#       4 DRIVER_PATH = '/Users/asiega/Development/chromedriver'
#       5
# ----> 6 run(HEADERS, DRIVER_PATH)
#
# <ipython-input-62-6fe72851b940> in run(headers, driver_path)
#      10     base_html = _scrape_pepper_page(driver_path)
#      11     base_data = [_extract_hotstuff_pepper_info(row) for row in base_html[1:]] # skip colheader
# ---> 12     base_data = pd.DataFrame(base_data)
#      13     base_data["source_name"] = "Uncle Steve's Hot Stuff"
#      14     print("%d peppers fetched from HotStuff!" % len(base_data))
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     261                     if com.is_named_tuple(data[0]) and columns is None:
#     262                         columns = data[0]._fields
# --> 263                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     264                     columns = _ensure_index(columns)
#     265
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    5353     elif isinstance(data[0], collections.Mapping):
#    5354         return _list_of_dict_to_arrays(data, columns,
# -> 5355                                        coerce_float=coerce_float, dtype=dtype)
#    5356     elif isinstance(data[0], Series):
#    5357         return _list_of_series_to_arrays(data, columns,
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in _list_of_dict_to_arrays(data, columns, coerce_float, dtype)
#    5469     if columns is None:
#    5470         gen = (list(x.keys()) for x in data)
# -> 5471         columns = lib.fast_unique_multiple_list_gen(gen)
#    5472
#    5473     # assure that they are of the base dict class and not of derived
#
# pandas/lib.pyx in pandas.lib.fast_unique_multiple_list_gen (pandas/lib.c:10190)()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in <genexpr>(.0)
#    5468 def _list_of_dict_to_arrays(data, columns, coerce_float=False, dtype=None):
#    5469     if columns is None:
# -> 5470         gen = (list(x.keys()) for x in data)
#    5471         columns = lib.fast_unique_multiple_list_gen(gen)
#    5472
#
# AttributeError: 'NoneType' object has no attribute 'keys'
